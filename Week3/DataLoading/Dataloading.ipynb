# %%
import pandas as pd
import sqlite3
from loguru import logger

doel_conn = sqlite3.connect('../../Source Data Model/BikeToDrive_V3_OLTP.db', timeout=30)
doel_cursor = doel_conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 5
#       2 import sqlite3
#       3 from loguru import logger
# ----> 5 doel_conn = sqlite3.connect('../Source Data Model/BikeToDrive_V3_OLTP.db', timeout=30)
#       6 doel_cursor = doel_conn.cursor()
#
# OperationalError: unable to open database file

# %% [markdown]
# Accessoire_Inkoop

# %%
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_4_Accessoire_Inkoop.db')
source_cursor = source_conn.cursor()

# Delete voor Full Refresh
alle_tabellen = [
    'Accessoire_Inkoop_Leverancier',
    'Accessoire_Inkoop_Accessoire',
    'Accessoire_Inkoop'
]

# We draaien de volgorde van de tabellen om.
alle_tabellen = alle_tabellen[::-1]

# We deleten alles van onze bestaande OLTP database
for tabel in alle_tabellen:
    delete_statement = f"DELETE FROM {tabel};"
    try:
        doel_cursor.execute(delete_statement)
    except Exception as e:
        logger.warning(f"FAILED: {delete_statement} ({e})")
        continue

# Commit na delete
doel_conn.commit()

source_cursor.execute("SELECT * FROM Leverancier")
Leverancier = source_cursor.fetchall()
for row in Leverancier:
    insert_statement = "INSERT INTO Accessoire_Inkoop_Leverancier VALUES ("
    # leveranciernr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + row[1] + "', "
    # adres
    insert_statement += "'" + row[2] + "', "
    # woonplaats
    insert_statement += "'" + row[3] + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Accessoire")
Accessoire = source_cursor.fetchall()

for row in Accessoire:
    insert_statement = "INSERT INTO Accessoire_Inkoop_Accessoire VALUES ("
    # accessoirenr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + row[1] + "', "
    # standaardprijs
    insert_statement += str(row[2]) + ", "
    # inkoopprijs
    insert_statement += str(row[3]) + ", "
    # soort
    insert_statement += "'" + row[4] + "', "
    # leverancier (FK)
    insert_statement += str(row[5])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Accessoire_Inkoop")
Accessoire_Inkoop = source_cursor.fetchall()
for row in Accessoire_Inkoop:
    insert_statement = "INSERT INTO Accessoire_Inkoop VALUES ("
    # inkoopnr (PK)
    insert_statement += str(row[0]) + ", "
    # inkoopmaand
    insert_statement += str(row[1]) + ", "
    # inkoopjaar
    insert_statement += str(row[2]) + ", "
    # aantal
    insert_statement += str(row[3]) + ", "
    # accessoire (FK)
    insert_statement += str(row[4])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

doel_conn.commit()
source_cursor.close()
doel_cursor.close()
source_conn.close()
doel_conn.close()

# %% [markdown]
# Accessoire_Verkoop

# %%
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_1_Accessoireverkoop.db')
source_cursor = source_conn.cursor()

# Delete voor Full Refresh
alle_tabellen = [
    'Accessoire_Verkoop',
    'Accessoire_Verkoop_Monteur',
    'Accessoire_Verkoop_Filiaal',
    'Accessoire_Verkoop_Klant',
    'Accessoire_Verkoop_Accessoire',
    'Accessoire_Verkoop_Leverancier'
]

# We draaien de volgorde van de tabellen om.
alle_tabellen = alle_tabellen[::-1]

# We deleten alles van onze bestaande OLTP database
for tabel in alle_tabellen:
    delete_statement = f"DELETE FROM {tabel};"
    try:
        doel_cursor.execute(delete_statement)
    except Exception as e:
        logger.warning(f"FAILED: {delete_statement} ({e})")
        continue

# Commit na delete
doel_conn.commit()

source_cursor.execute("SELECT * FROM Leverancier")
Leverancier = source_cursor.fetchall()
for row in Leverancier:   
    insert_statement = "INSERT INTO Accessoire_Verkoop_Leverancier VALUES ("
    # leveranciernr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + row[1] + "', "
    # adres
    insert_statement += "'" + row[2] + "', "
    # woonplaats
    insert_statement += "'" + row[3] + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Accessoire")
Accessoire = source_cursor.fetchall()

for row in Accessoire:
    insert_statement = "INSERT INTO Accessoire_Verkoop_Accessoire VALUES ("
    # accessoirenr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + row[1] + "', "
    # standaardprijs
    insert_statement += str(row[2]) + ", "
    # inkoopprijs
    insert_statement += str(row[3]) + ", "
    # soort
    insert_statement += "'" + row[4] + "', "
    # leverancier (FK)
    insert_statement += str(row[5])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Klant")
Klant = source_cursor.fetchall()
for row in Klant:
    insert_statement = "INSERT INTO Accessoire_Verkoop_Klant VALUES ("
    # klantnr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + row[1] + "', "
    # adres
    insert_statement += "'" + row[2] + "', "
    # woonplaats
    insert_statement += "'" + row[3] + "', "
    # geslacht
    insert_statement += "'" + row[4] + "', "
    # geboortedatum
    insert_statement += "'" + row[5] + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Filiaal")
Filiaal = source_cursor.fetchall()
for row in Filiaal:
    insert_statement = "INSERT INTO Accessoire_Verkoop_Filiaal VALUES ("
    # filiaalnr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + row[1] + "', "
    # adres
    insert_statement += "'" + row[2] + "', "
    # provincie
    insert_statement += "'" + row[3] + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Monteur")
Monteur = source_cursor.fetchall()
for row in Monteur:
    insert_statement = "INSERT INTO Accessoire_Verkoop_Monteur VALUES ("
    #monteurnr (PK)
    insert_statement += str(row[0]) + ", "
    #naam
    insert_statement += "'" + row[1] + "', "
    #woonplaats
    insert_statement += "'" + row[2] + "', "
    #uurloon
    insert_statement += str(row[3])  + ", "
    #filiaal (PK)
    insert_statement += str(row[4])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")


source_cursor.execute("SELECT * FROM Accessoire_Verkoop")
Accessoire_Verkoop = source_cursor.fetchall()
for row in Accessoire_Verkoop:
    insert_statement = "INSERT INTO Accessoire_Verkoop VALUES ("
    #accessoire_verkoopnr
    insert_statement += str(row[0]) + ", "
    #datum
    insert_statement += str(row[1]) + ", "
    #aantal
    insert_statement += str(row[2]) + ", "
    #verkoopprijs
    insert_statement += str(row[3]) + ", "
    # klant (FK)
    insert_statement += str(row[4]) + ", "
    # accessoire (FK)
    insert_statement += str(row[5]) + ", "
    # monteur (FK)
    insert_statement += str(row[6])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

doel_conn.commit()
source_cursor.close()
doel_cursor.close()
source_conn.close()
doel_conn.close()

# %% [markdown]
# Onderhoud

# %%
# We maken eerst connectie met de bron.
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_3_Onderhoud.db')
source_cursor = source_conn.cursor()

# Lijst met alle tabellen die geleegd moeten worden.
alle_tabellen = [
    'Onderhoud_Fabrikant',
    'Onderhoud_Filiaal',
    'Onderhoud_Fiets',
    'Onderhoud_Monteur',
    'Onderhoud'
]

# We draaien de volgorde van de tabellen om.
alle_tabellen = alle_tabellen[::-1]

# We deleten alles van onze bestaande OLTP database
for tabel in alle_tabellen:
    delete_statement = f"DELETE FROM {tabel};"
    try:
        doel_cursor.execute(delete_statement)
    except Exception as e:
        logger.warning(f"FAILED: {delete_statement} ({e})")
        continue

# Commit na delete
doel_conn.commit()

# 1. Onderhoud_Fabrikant

source_cursor.execute("SELECT * FROM Fabrikant")
Fabrikant = source_cursor.fetchall()

for row in Fabrikant:
    insert_statement = "INSERT INTO Onderhoud_Fabrikant VALUES ("   
    # fabrikantnr (PK)
    insert_statement += str(row[0]) + ", "   
    # naam
    insert_statement += "'" + str(row[1]) + "', "   
    # adres
    insert_statement += "'" + str(row[2]) + "', "   
    # plaats
    insert_statement += "'" + str(row[3]) + "'"   
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

# 2. Onderhoud_Fiets

source_cursor.execute("SELECT * FROM Fiets")
Fiets = source_cursor.fetchall()

for row in Fiets:
    insert_statement = "INSERT INTO Onderhoud_Fiets VALUES ("    
    # fietsnr (PK)
    insert_statement += str(row[0]) + ", "    
    # soort
    insert_statement += "'" + str(row[1]) + "', "    
    # merk
    insert_statement += "'" + str(row[2]) + "', "  
    # type
    insert_statement += "'" + str(row[3]) + "', "   
    # standaardprijs
    insert_statement += str(row[4]) + ", "  
    # inkoopprijs
    insert_statement += str(row[5]) + ", "   
    # kleur
    insert_statement += "'" + str(row[6]) + "', "   
    # fabrikant (FK)
    insert_statement += str(row[7])    
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

# 3. Onderhoud_Filiaal
source_cursor.execute("SELECT * FROM Filiaal")
Filiaal = source_cursor.fetchall()

for row in Filiaal:
    insert_statement = "INSERT INTO Onderhoud_Filiaal VALUES ("
    # filiaalnr (PK)
    insert_statement += str(row[0]) + ", " 
    # naam
    insert_statement += "'" + str(row[1]) + "', " 
    # adres
    insert_statement += "'" + str(row[2]) + "', "  
    # provincie
    insert_statement += "'" + str(row[3]) + "'"   
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

# 4. Onderhoud_Monteur
source_cursor.execute("SELECT * FROM Monteur")
Monteur = source_cursor.fetchall()

for row in Monteur:
    insert_statement = "INSERT INTO Onderhoud_Monteur VALUES ("
    # monteurnr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + str(row[1]) + "', "
    # woonplaats
    insert_statement += "'" + str(row[2]) + "', "  
    # uurloon
    insert_statement += str(row[3]) + ", "   
    # filiaal (FK)
    insert_statement += str(row[4])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

# 5. Onderhoud

source_cursor.execute("SELECT * FROM Onderhoud")
Onderhoud = source_cursor.fetchall()

for row in Onderhoud:
    insert_statement = "INSERT INTO Onderhoud VALUES ("
    # onderhoudnr (PK)
    insert_statement += str(row[0]) + ", "
    # datum
    insert_statement += "'" + str(row[1]) + "', "
    # starttijd
    insert_statement += "'" + str(row[2]) + "', "
    # eindtijd
    insert_statement += "'" + str(row[3]) + "', "
    # fiets (FK)
    insert_statement += str(row[4]) + ", "
    # monteur (FK)
    insert_statement += str(row[5])    
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")


# Committen van de wijzigingen
doel_conn.commit()

# Connecties sluiten
source_cursor.close()
source_conn.close()
doel_cursor.close()
doel_conn.close()

# %% [markdown]
# Fiets_Inkoop

# %%
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_5_Fiets_Inkoop.db')
source_cursor = source_conn.cursor()

# Lijst met alle tabellen die geleegd moeten worden.
alle_tabellen = [
    'Fiets_Inkoop',
    'Fiets_Inkoop_Fiets',
    'Fiets_Inkoop_Fabrikant',
]

# We draaien de volgorde van de tabellen om.
alle_tabellen = alle_tabellen[::-1]

# We deleten alles van onze bestaande OLTP database
for tabel in alle_tabellen:
    delete_statement = f"DELETE FROM {tabel};"
    try:
        doel_cursor.execute(delete_statement)
    except Exception as e:
        logger.warning(f"FAILED: {delete_statement} ({e})")
        continue

# Commit na delete
doel_conn.commit()

source_cursor.execute("SELECT * FROM Fabrikant")
Fabrikant = source_cursor.fetchall()
for row in Fabrikant:
    insert_statement = "INSERT INTO Fiets_Inkoop_Fabrikant VALUES ("
    # fabrikantnr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + row[1] + "', "
    # adres
    insert_statement += "'" + row[2] + "', "
    # plaats
    insert_statement += "'" + row[3] + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Fiets")
Fiets = source_cursor.fetchall()

for row in Fiets:
    insert_statement = "INSERT INTO Fiets_Inkoop_Fiets VALUES ("
    # fietsnr (PK)
    insert_statement += str(row[0]) + ", "
    # soort
    insert_statement += "'" + row[1] + "', "
    # merk
    insert_statement += "'" + row[2] + "', "
    # type
    insert_statement += "'" + row[3] + "', "
    # standaardprijs
    insert_statement += str(row[4]) + ", "
    # inkoopprijs
    insert_statement += str(row[5]) + ", "
    # kleur
    insert_statement += "'" + row[6] + "', "
    # fabrikant (FK)
    insert_statement += str(row[7])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Fiets_Inkoop")
Fiets_Inkoop = source_cursor.fetchall()
for row in Fiets_Inkoop:
    insert_statement = "INSERT INTO Fiets_Inkoop VALUES ("
    # inkoopnr (PK)
    insert_statement += str(row[0]) + ", "
    # inkoopmaand
    insert_statement += str(row[1]) + ", "
    # inkoopjaar
    insert_statement += str(row[2]) + ", "
    # aantal
    insert_statement += str(row[3]) + ", "
    # fiets(FK)
    insert_statement += str(row[4])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

doel_conn.commit()
source_cursor.close()
doel_cursor.close()
source_conn.close()
doel_conn.close()

# %% [markdown]
# Fiets_Verkoop

# %%
# We maken eerst connectie met de bron.
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_2_Fietsverkoop.db')
source_cursor = source_conn.cursor()

# Lijst met alle tabellen die geleegd moeten worden.
alle_tabellen = [
    'Fiets_Verkoop_Fabrikant',
    'Fiets_Verkoop_Filiaal',
    'Fiets_Verkoop_Fiets',
    'Fiets_Verkoop_Monteur',
    'Fiets_Verkoop_Klant',
    'Fiets_Verkoop'
]

# We draaien de volgorde van de tabellen om.
alle_tabellen = alle_tabellen[::-1]

# We deleten alles van onze bestaande OLTP database
for tabel in alle_tabellen:
    delete_statement = f"DELETE FROM {tabel};"
    try:
        doel_cursor.execute(delete_statement)
    except Exception as e:
        logger.warning(f"FAILED: {delete_statement} ({e})")
        continue

# Commit na delete
doel_conn.commit()

# De SQL Query die alles selecteert vanuit de Operationele Database.
# We gaan eerst het tabel Fabrikant inserten in onze OLTP.
source_cursor.execute("SELECT * FROM Fabrikant")
Fabrikant = source_cursor.fetchall()

# 1. Fiets_Verkoop_Fabrikant
for row in Fabrikant:
    insert_statement = "INSERT INTO Fiets_Verkoop_Fabrikant VALUES ("
    # fabrikantnr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + row[1] + "', "
    # adres
    insert_statement += "'" + row[2] + "', "
    # plaats
    insert_statement += "'" + row[3] + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

# 2. Fiets
source_cursor.execute("SELECT * FROM Fiets")
Fiets = source_cursor.fetchall()

for row in Fiets:
    insert_statement = "INSERT INTO Fiets_Verkoop_Fiets VALUES ("
    # fietsnr (PK)
    insert_statement += str(row[0]) + ", "
    # soort
    insert_statement += "'" + row[1] + "', "
    # merk
    insert_statement += "'" + row[2] + "', "
    # type
    insert_statement += "'" + row[3] + "', "
    # standaardprijs
    insert_statement += str(row[4]) + ", "
    # inkoopprijs
    insert_statement += str(row[5]) + ", "
    # kleur
    insert_statement += "'" + str(row[6]) + "', "
    # fabrikant (FK)
    insert_statement += str(row[7])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

# 3. Filiaal
source_cursor.execute("SELECT * FROM Filiaal")
Filiaal = source_cursor.fetchall()

for row in Filiaal:
    insert_statement = "INSERT INTO Fiets_Verkoop_Filiaal VALUES ("
    # filiaalnr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + str(row[1]) + "', "
    # adres
    insert_statement += "'" + str(row[2]) + "', "
    # postcode moet provincie zijn in OLTP fout!.
    insert_statement += "'" + str(row[3]) + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

# 4. Monteur
source_cursor.execute("SELECT * FROM Monteur")
Monteur = source_cursor.fetchall()

for row in Monteur:
    insert_statement = "INSERT INTO Fiets_Verkoop_Monteur VALUES ("
    # monteurnr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + str(row[1]) + "', "
    # woonplaats
    insert_statement += "'" + str(row[2]) + "', "
    # uurloon
    insert_statement += str(row[3]) + ", "
    # filiaal (FK)
    insert_statement += str(row[4])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

# 5. Klant
source_cursor.execute("SELECT * FROM Klant")
Klant = source_cursor.fetchall()

for row in Klant:
    insert_statement = "INSERT INTO Fiets_Verkoop_Klant VALUES ("
    # klantnr (PK)
    insert_statement += str(row[0]) + ", "
    # naam
    insert_statement += "'" + str(row[1]) + "', "
    # adres
    insert_statement += "'" + str(row[2]) + "', "
    # woonplaats
    insert_statement += "'" + str(row[3]) + "', "
    # geslacht
    insert_statement += "'" + str(row[4]) + "', "
    # geboortedatum
    insert_statement += "'" + str(row[5]) + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

# 6. Verkoop
source_cursor.execute("SELECT * FROM Fiets_Verkoop")
Verkoop = source_cursor.fetchall()

for row in Verkoop:
    insert_statement = "INSERT INTO Fiets_Verkoop VALUES ("
    # fiets_verkoopnr (PK)
    insert_statement += str(row[0]) + ", "
    # datum
    insert_statement += "'" + str(row[1]) + "', "
    # aantal
    insert_statement += str(row[2]) + ", "
    # verkoopprijs
    insert_statement += str(row[3]) + ", "
    # klant (FK)
    insert_statement += str(row[4]) + ", "
    # fiets (FK)
    insert_statement += str(row[5]) + ", "
    # monteur (FK)
    insert_statement += str(row[6])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

# We committen onze gewijzigde acties.
doel_conn.commit()
source_cursor.close()
source_conn.close()
doel_cursor.close()
doel_conn.close()
# Out:
# 2026-03-25 16:53:14.379 | WARNING  | __main__:<module>:24 - FAILED: DELETE FROM Fiets_Verkoop; (no such table: Fiets_Verkoop)
# 2026-03-25 16:53:14.384 | WARNING  | __main__:<module>:24 - FAILED: DELETE FROM Fiets_Verkoop_Klant; (no such table: Fiets_Verkoop_Klant)
# 2026-03-25 16:53:14.388 | WARNING  | __main__:<module>:24 - FAILED: DELETE FROM Fiets_Verkoop_Monteur; (no such table: Fiets_Verkoop_Monteur)
# 2026-03-25 16:53:14.391 | WARNING  | __main__:<module>:24 - FAILED: DELETE FROM Fiets_Verkoop_Fiets; (no such table: Fiets_Verkoop_Fiets)
# 2026-03-25 16:53:14.393 | WARNING  | __main__:<module>:24 - FAILED: DELETE FROM Fiets_Verkoop_Filiaal; (no such table: Fiets_Verkoop_Filiaal)
# 2026-03-25 16:53:14.394 | WARNING  | __main__:<module>:24 - FAILED: DELETE FROM Fiets_Verkoop_Fabrikant; (no such table: Fiets_Verkoop_Fabrikant)
# 2026-03-25 16:53:14.398 | WARNING  | __main__:<module>:51 - FAILED: INSERT INTO Fiets_Verkoop_Fabrikant VALUES (1, 'SpeedCycle BV', 'Spoorstraat 12', 'Eindhoven');
# 2026-03-25 16:53:14.402 | WARNING  | __main__:<module>:51 - FAILED: INSERT INTO Fiets_Verkoop_Fabrikant VALUES (2, 'UrbanBike Co.', 'Keizersgracht 45', 'Amsterdam');
# 2026-03-25 16:53:14.405 | WARNING  | __main__:<module>:51 - FAILED: INSERT INTO Fiets_Verkoop_Fabrikant VALUES (3, 'HollandRider', 'Marktstraat 9', 'Utrecht');
# 2026-03-25 16:53:14.408 | WARNING  | __main__:<module>:51 - FAILED: INSERT INTO Fiets_Verkoop_Fabrikant VALUES (4, 'EcoWheelers', 'Kade 33', 'Delft');
# 2026-03-25 16:53:14.411 | WARNING  | __main__:<module>:51 - FAILED: INSERT INTO Fiets_Verkoop_Fabrikant VALUES (5, 'DutchMotion', 'Westplein 7', 'Rotterdam');
# 2026-03-25 16:53:14.413 | WARNING  | __main__:<module>:51 - FAILED: INSERT INTO Fiets_Verkoop_Fabrikant VALUES (6, 'NordicBike', 'Prinsestraat 18', 'Groningen');
# 2026-03-25 16:53:14.416 | WARNING  | __main__:<module>:51 - FAILED: INSERT INTO Fiets_Verkoop_Fabrikant VALUES (7, 'CycleTech', 'Boslaan 60', 'Den Haag');
# 2026-03-25 16:53:14.423 | WARNING  | __main__:<module>:51 - FAILED: INSERT INTO Fiets_Verkoop_Fabrikant VALUES (8, 'GreenGear', 'Leliestraat 24', 'Nijmegen');
# 2026-03-25 16:53:14.425 | WARNING  | __main__:<module>:51 - FAILED: INSERT INTO Fiets_Verkoop_Fabrikant VALUES (9, 'FastFrame', 'Rivierlaan 3', 'Maastricht');
# 2026-03-25 16:53:14.427 | WARNING  | __main__:<module>:51 - FAILED: INSERT INTO Fiets_Verkoop_Fabrikant VALUES (10, 'OranjeFiets', 'Brink 88', 'Zwolle');
# 2026-03-25 16:53:14.431 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (1, 'Stadsfiets', 'SpeedCycle', 'STA-240', 962.33, 815.25, 'Groen', 1);
# 2026-03-25 16:53:14.435 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (2, 'Mountainbike', 'SpeedCycle', 'MOU-394', 890.64, 733.06, 'Zwart', 1);
# 2026-03-25 16:53:14.438 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (3, 'Mountainbike', 'SpeedCycle', 'MOU-341', 547.79, 472.47, 'Geel', 1);
# 2026-03-25 16:53:14.441 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (4, 'Racefiets', 'SpeedCycle', 'RAC-241', 991.75, 787.67, 'Groen', 1);
# 2026-03-25 16:53:14.443 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (5, 'Mountainbike', 'SpeedCycle', 'MOU-566', 879.44, 778.29, 'Geel', 1);
# 2026-03-25 16:53:14.446 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (6, 'Mountainbike', 'SpeedCycle', 'MOU-307', 416.21, 353.06, 'Geel', 1);
# 2026-03-25 16:53:14.448 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (7, 'Mountainbike', 'SpeedCycle', 'MOU-979', 592.74, 460.25, 'Wit', 1);
# 2026-03-25 16:53:14.451 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (8, 'Stadsfiets', 'SpeedCycle', 'STA-863', 783.16, 604.83, 'Geel', 1);
# 2026-03-25 16:53:14.454 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (9, 'Racefiets', 'SpeedCycle', 'RAC-395', 649.93, 557.77, 'Rood', 1);
# 2026-03-25 16:53:14.457 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (10, 'Racefiets', 'SpeedCycle', 'RAC-544', 752.38, 591.75, 'Blauw', 1);
# 2026-03-25 16:53:14.460 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (11, 'Elektrische fiets', 'SpeedCycle', 'ELE-758', 629.12, 486.19, 'Groen', 1);
# 2026-03-25 16:53:14.462 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (12, 'Racefiets', 'SpeedCycle', 'RAC-837', 1042.23, 818.66, 'Rood', 1);
# 2026-03-25 16:53:14.465 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (13, 'Racefiets', 'SpeedCycle', 'RAC-518', 474.07, 366.5, 'Rood', 1);
# 2026-03-25 16:53:14.468 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (14, 'Mountainbike', 'SpeedCycle', 'MOU-952', 1097.88, 892.11, 'Geel', 1);
# 2026-03-25 16:53:14.471 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (15, 'Elektrische fiets', 'SpeedCycle', 'ELE-975', 363.82, 319.6, 'Geel', 1);
# 2026-03-25 16:53:14.472 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (16, 'Elektrische fiets', 'UrbanBike', 'ELE-880', 968.23, 814.67, 'Geel', 2);
# 2026-03-25 16:53:14.474 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (17, 'Mountainbike', 'UrbanBike', 'MOU-689', 959.6, 744.56, 'Groen', 2);
# 2026-03-25 16:53:14.476 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (18, 'Mountainbike', 'UrbanBike', 'MOU-268', 800.78, 714.39, 'Groen', 2);
# 2026-03-25 16:53:14.478 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (19, 'Racefiets', 'UrbanBike', 'RAC-866', 900.69, 794.46, 'Blauw', 2);
# 2026-03-25 16:53:14.480 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (20, 'Mountainbike', 'UrbanBike', 'MOU-889', 815.7, 693.41, 'Grijs', 2);
# 2026-03-25 16:53:14.482 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (21, 'Racefiets', 'UrbanBike', 'RAC-442', 798.95, 644.12, 'Zwart', 2);
# 2026-03-25 16:53:14.484 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (22, 'Mountainbike', 'UrbanBike', 'MOU-108', 508.52, 426.28, 'Rood', 2);
# 2026-03-25 16:53:14.487 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (23, 'Mountainbike', 'UrbanBike', 'MOU-349', 898.12, 802.74, 'Zwart', 2);
# 2026-03-25 16:53:14.489 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (24, 'Racefiets', 'UrbanBike', 'RAC-590', 1059.72, 837.27, 'Grijs', 2);
# 2026-03-25 16:53:14.491 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (25, 'Racefiets', 'UrbanBike', 'RAC-878', 393.02, 327.63, 'Geel', 2);
# 2026-03-25 16:53:14.493 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (26, 'Mountainbike', 'UrbanBike', 'MOU-620', 834.1, 725.11, 'Blauw', 2);
# 2026-03-25 16:53:14.496 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (27, 'Elektrische fiets', 'UrbanBike', 'ELE-176', 463.34, 384.41, 'Rood', 2);
# 2026-03-25 16:53:14.498 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (28, 'Stadsfiets', 'HollandRider', 'STA-654', 825.49, 642.36, 'Zwart', 3);
# 2026-03-25 16:53:14.500 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (29, 'Racefiets', 'HollandRider', 'RAC-187', 866.77, 682.49, 'Grijs', 3);
# 2026-03-25 16:53:14.503 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (30, 'Mountainbike', 'HollandRider', 'MOU-798', 878.94, 684.17, 'Geel', 3);
# 2026-03-25 16:53:14.505 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (31, 'Elektrische fiets', 'HollandRider', 'ELE-142', 984.45, 808.72, 'Blauw', 3);
# 2026-03-25 16:53:14.506 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (32, 'Stadsfiets', 'HollandRider', 'STA-776', 750.07, 583.64, 'Zwart', 3);
# 2026-03-25 16:53:14.509 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (33, 'Stadsfiets', 'HollandRider', 'STA-850', 972.96, 871.21, 'Zwart', 3);
# 2026-03-25 16:53:14.511 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (34, 'Stadsfiets', 'HollandRider', 'STA-654', 923.67, 759.53, 'Grijs', 3);
# 2026-03-25 16:53:14.513 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (35, 'Elektrische fiets', 'HollandRider', 'ELE-515', 955.64, 823.18, 'Wit', 3);
# 2026-03-25 16:53:14.515 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (36, 'Stadsfiets', 'HollandRider', 'STA-929', 778.05, 606.0, 'Grijs', 3);
# 2026-03-25 16:53:14.517 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (37, 'Stadsfiets', 'HollandRider', 'STA-303', 930.18, 785.13, 'Rood', 3);
# 2026-03-25 16:53:14.519 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (38, 'Racefiets', 'EcoWheelers', 'RAC-898', 341.93, 310.3, 'Rood', 4);
# 2026-03-25 16:53:14.521 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (39, 'Elektrische fiets', 'EcoWheelers', 'ELE-368', 909.73, 755.03, 'Wit', 4);
# 2026-03-25 16:53:14.523 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (40, 'Racefiets', 'EcoWheelers', 'RAC-216', 1009.79, 869.68, 'Geel', 4);
# 2026-03-25 16:53:14.526 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (41, 'Racefiets', 'EcoWheelers', 'RAC-155', 405.1, 327.81, 'Wit', 4);
# 2026-03-25 16:53:14.529 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (42, 'Stadsfiets', 'EcoWheelers', 'STA-435', 483.41, 372.38, 'Grijs', 4);
# 2026-03-25 16:53:14.531 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (43, 'Elektrische fiets', 'EcoWheelers', 'ELE-574', 913.68, 780.62, 'Grijs', 4);
# 2026-03-25 16:53:14.533 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (44, 'Mountainbike', 'EcoWheelers', 'MOU-622', 738.2, 657.59, 'Blauw', 4);
# 2026-03-25 16:53:14.536 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (45, 'Mountainbike', 'EcoWheelers', 'MOU-420', 922.82, 774.07, 'Geel', 4);
# 2026-03-25 16:53:14.538 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (46, 'Stadsfiets', 'EcoWheelers', 'STA-677', 681.36, 608.95, 'Zwart', 4);
# 2026-03-25 16:53:14.540 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (47, 'Mountainbike', 'FastFrame', 'MOU-341', 837.18, 722.64, 'Geel', 5);
# 2026-03-25 16:53:14.543 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (48, 'Mountainbike', 'FastFrame', 'MOU-623', 972.19, 765.47, 'Zwart', 5);
# 2026-03-25 16:53:14.545 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (49, 'Mountainbike', 'FastFrame', 'MOU-996', 489.22, 383.92, 'Groen', 5);
# 2026-03-25 16:53:14.547 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (50, 'Stadsfiets', 'FastFrame', 'STA-250', 606.6, 511.85, 'Groen', 5);
# 2026-03-25 16:53:14.548 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (51, 'Elektrische fiets', 'FastFrame', 'ELE-398', 494.53, 393.42, 'Grijs', 5);
# 2026-03-25 16:53:14.550 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (52, 'Elektrische fiets', 'FastFrame', 'ELE-152', 420.23, 360.9, 'Geel', 5);
# 2026-03-25 16:53:14.552 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (53, 'Mountainbike', 'FastFrame', 'MOU-512', 1052.51, 885.18, 'Zwart', 5);
# 2026-03-25 16:53:14.553 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (54, 'Racefiets', 'FastFrame', 'RAC-635', 1114.8, 883.25, 'Wit', 5);
# 2026-03-25 16:53:14.556 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (55, 'Racefiets', 'NordicBike', 'RAC-941', 696.98, 594.26, 'Blauw', 6);
# 2026-03-25 16:53:14.558 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (56, 'Mountainbike', 'NordicBike', 'MOU-648', 548.79, 465.36, 'Geel', 6);
# 2026-03-25 16:53:14.561 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (57, 'Racefiets', 'NordicBike', 'RAC-775', 682.44, 582.91, 'Groen', 6);
# 2026-03-25 16:53:14.564 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (58, 'Elektrische fiets', 'NordicBike', 'ELE-170', 551.27, 489.2, 'Groen', 6);
# 2026-03-25 16:53:14.567 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (59, 'Elektrische fiets', 'NordicBike', 'ELE-383', 710.72, 592.5, 'Rood', 6);
# 2026-03-25 16:53:14.570 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (60, 'Stadsfiets', 'NordicBike', 'STA-878', 572.85, 462.2, 'Wit', 6);
# 2026-03-25 16:53:14.572 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (61, 'Elektrische fiets', 'CycleTech', 'ELE-935', 887.87, 684.66, 'Blauw', 7);
# 2026-03-25 16:53:14.574 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (62, 'Racefiets', 'CycleTech', 'RAC-923', 620.11, 549.7, 'Zwart', 7);
# 2026-03-25 16:53:14.575 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (63, 'Mountainbike', 'CycleTech', 'MOU-425', 570.34, 495.14, 'Grijs', 7);
# 2026-03-25 16:53:14.577 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (64, 'Stadsfiets', 'CycleTech', 'STA-131', 744.15, 640.22, 'Groen', 7);
# 2026-03-25 16:53:14.580 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (65, 'Mountainbike', 'CycleTech', 'MOU-741', 638.59, 559.34, 'Zwart', 7);
# 2026-03-25 16:53:14.582 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (66, 'Elektrische fiets', 'GreenGear', 'ELE-580', 876.34, 696.3, 'Zwart', 8);
# 2026-03-25 16:53:14.585 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (67, 'Racefiets', 'GreenGear', 'RAC-335', 556.06, 500.99, 'Zwart', 8);
# 2026-03-25 16:53:14.588 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (68, 'Elektrische fiets', 'GreenGear', 'ELE-951', 980.16, 813.45, 'Rood', 8);
# 2026-03-25 16:53:14.589 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (69, 'Racefiets', 'GreenGear', 'RAC-877', 811.08, 675.26, 'Zwart', 8);
# 2026-03-25 16:53:14.591 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (70, 'Racefiets', 'FastFrame', 'RAC-965', 490.58, 403.35, 'Blauw', 9);
# 2026-03-25 16:53:14.592 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (71, 'Elektrische fiets', 'FastFrame', 'ELE-120', 731.83, 576.62, 'Grijs', 9);
# 2026-03-25 16:53:14.595 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (72, 'Racefiets', 'FastFrame', 'RAC-797', 399.31, 327.02, 'Rood', 9);
# 2026-03-25 16:53:14.598 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (73, 'Stadsfiets', 'OranjeFiets', 'STA-974', 731.99, 622.99, 'Geel', 10);
# 2026-03-25 16:53:14.602 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (74, 'Racefiets', 'OranjeFiets', 'RAC-701', 589.5, 513.51, 'Geel', 10);
# 2026-03-25 16:53:14.606 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (75, 'Elektrische fiets', 'OranjeFiets', 'ELE-507', 997.58, 772.38, 'Wit', 10);
# 2026-03-25 16:53:14.608 | WARNING  | __main__:<module>:80 - FAILED: INSERT INTO Fiets_Verkoop_Fiets VALUES (1500, 'Stadsfiets', 'Gazelle', 'Classic', 599.99, 400.0, 'Zwart', 1);
# 2026-03-25 16:53:14.613 | WARNING  | __main__:<module>:101 - FAILED: INSERT INTO Fiets_Verkoop_Filiaal VALUES (1, 'BikeWorld Amsterdam', 'Prinsengracht 100', 'Noord-Holland');
# 2026-03-25 16:53:14.615 | WARNING  | __main__:<module>:101 - FAILED: INSERT INTO Fiets_Verkoop_Filiaal VALUES (2, 'FietsGigant Haarlem', 'Grote Markt 22', 'Noord-Holland');
# 2026-03-25 16:53:14.617 | WARNING  | __main__:<module>:101 - FAILED: INSERT INTO Fiets_Verkoop_Filiaal VALUES (3, 'FietsExpress Rotterdam', 'Coolsingel 55', 'Zuid-Holland');
# 2026-03-25 16:53:14.620 | WARNING  | __main__:<module>:101 - FAILED: INSERT INTO Fiets_Verkoop_Filiaal VALUES (4, 'CycleCity Leiden', 'Breestraat 48', 'Zuid-Holland');
# 2026-03-25 16:53:14.624 | WARNING  | __main__:<module>:124 - FAILED: INSERT INTO Fiets_Verkoop_Monteur VALUES (1, 'Tom van Dijk', 'Amsterdam', 19.5, 1);
# 2026-03-25 16:53:14.626 | WARNING  | __main__:<module>:124 - FAILED: INSERT INTO Fiets_Verkoop_Monteur VALUES (2, 'Lisa Verhoeven', 'Amstelveen', 18.75, 1);
# 2026-03-25 16:53:14.629 | WARNING  | __main__:<module>:124 - FAILED: INSERT INTO Fiets_Verkoop_Monteur VALUES (3, 'Kevin Jaspers', 'Zaandam', 20.0, 1);
# 2026-03-25 16:53:14.631 | WARNING  | __main__:<module>:124 - FAILED: INSERT INTO Fiets_Verkoop_Monteur VALUES (4, 'Romy Willems', 'Haarlem', 17.8, 2);
# 2026-03-25 16:53:14.633 | WARNING  | __main__:<module>:124 - FAILED: INSERT INTO Fiets_Verkoop_Monteur VALUES (5, 'Daan de Groot', 'Rotterdam', 21.0, 3);
# 2026-03-25 16:53:14.636 | WARNING  | __main__:<module>:124 - FAILED: INSERT INTO Fiets_Verkoop_Monteur VALUES (6, 'Sophie de Leeuw', 'Schiedam', 19.9, 3);
# 2026-03-25 16:53:14.638 | WARNING  | __main__:<module>:124 - FAILED: INSERT INTO Fiets_Verkoop_Monteur VALUES (7, 'Mark van Vliet', 'Dordrecht', 20.25, 3);
# 2026-03-25 16:53:14.640 | WARNING  | __main__:<module>:124 - FAILED: INSERT INTO Fiets_Verkoop_Monteur VALUES (8, 'Jesse Peters', 'Leiden', 16.95, 4);
# 2026-03-25 16:53:14.643 | WARNING  | __main__:<module>:124 - FAILED: INSERT INTO Fiets_Verkoop_Monteur VALUES (9, 'Eva Meijer', 'Zoetermeer', 18.4, 4);
# 2026-03-25 16:53:14.646 | WARNING  | __main__:<module>:124 - FAILED: INSERT INTO Fiets_Verkoop_Monteur VALUES (10, 'Milan de Bruin', 'Zaandam', 17.25, 2);
# 2026-03-25 16:53:14.651 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (1, 'Jan Jansen', 'Kerkstraat 12', 'Amsterdam', 'M', '1985-03-22');
# 2026-03-25 16:53:14.653 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (2, 'Sophie de Boer', 'Lindelaan 8', 'Rotterdam', 'V', '1990-07-11');
# 2026-03-25 16:53:14.655 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (3, 'Pieter Visser', 'Havenstraat 3', 'Den Haag', 'M', '1978-11-05');
# 2026-03-25 16:53:14.658 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (4, 'Emma Smit', 'Boomgaard 22', 'Haarlem', 'V', '1995-02-18');
# 2026-03-25 16:53:14.660 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (5, 'Tom Bakker', 'Stationsweg 44', 'Leiden', 'M', '1982-09-09');
# 2026-03-25 16:53:14.662 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (6, 'Lisa Meijer', 'Dijkstraat 10', 'Zaandam', 'V', '1993-12-30');
# 2026-03-25 16:53:14.664 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (7, 'Bart de Vries', 'Brouwersgracht 7', 'Delft', 'M', '1976-06-06');
# 2026-03-25 16:53:14.666 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (8, 'Julia van Dijk', 'Plataanlaan 5', 'Hoorn', 'V', '2000-01-15');
# 2026-03-25 16:53:14.669 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (9, 'Kevin Mol', 'Singel 99', 'Alkmaar', 'M', '1989-08-01');
# 2026-03-25 16:53:14.672 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (10, 'Nina Groen', 'Waterstraat 16', 'Schiedam', 'V', '1991-05-25');
# 2026-03-25 16:53:14.674 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (11, 'Daan Willems', 'Parklaan 31', 'Haarlem', 'M', '1987-10-12');
# 2026-03-25 16:53:14.676 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (12, 'Eva Vos', 'Zomerweg 2', 'Zoetermeer', 'V', '1996-04-03');
# 2026-03-25 16:53:14.678 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (13, 'Rik de Jong', 'Noorderstraat 88', 'Hilversum', 'M', '1980-12-21');
# 2026-03-25 16:53:14.680 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (14, 'Mila Kuipers', 'Heemraadssingel 15', 'Rotterdam', 'V', '1998-09-17');
# 2026-03-25 16:53:14.682 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (15, 'Sam Reinders', 'Beethovenlaan 13', 'Haarlem', 'M', '1983-01-29');
# 2026-03-25 16:53:14.685 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (16, 'Robin Dekker', 'Rozenstraat 4', 'Delft', 'M', '1992-11-23');
# 2026-03-25 16:53:14.688 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (17, 'Lieke de Wit', 'Tulpenpad 19', 'Den Haag', 'V', '1986-07-12');
# 2026-03-25 16:53:14.690 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (18, 'Jeroen Hermans', 'Klaprooslaan 6', 'Zaandam', 'M', '1999-05-04');
# 2026-03-25 16:53:14.693 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (19, 'Tessa van Vliet', 'Nieuwstraat 12', 'Leiden', 'V', '2001-03-18');
# 2026-03-25 16:53:14.695 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (20, 'Bas Hendriks', 'IJsselstraat 2', 'Rotterdam', 'M', '1984-10-30');
# 2026-03-25 16:53:14.696 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (21, 'Luna Hoekstra', 'Hortensialaan 1', 'Amstelveen', 'V', '1997-08-07');
# 2026-03-25 16:53:14.698 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (22, 'Noah de Groot', 'Burgemeesterlaan 9', 'Haarlem', 'M', '1990-12-02');
# 2026-03-25 16:53:14.708 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (23, 'Amber Peeters', 'Merellaan 18', 'Hoofddorp', 'V', '1995-06-21');
# 2026-03-25 16:53:14.712 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (24, 'Mats Jonker', 'Kasteelstraat 7', 'Schiedam', 'M', '1988-01-05');
# 2026-03-25 16:53:14.714 | WARNING  | __main__:<module>:149 - FAILED: INSERT INTO Fiets_Verkoop_Klant VALUES (25, 'Isis Mulder', 'Goudenregenstraat 11', 'Dordrecht', 'V', '2000-09-28');
# 2026-03-25 16:53:14.719 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (1, '2024-03-09', 3, 1020.48, 25, 61, 6);
# 2026-03-25 16:53:14.723 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (2, '2024-07-12', 1, 1391.84, 23, 58, 5);
# 2026-03-25 16:53:14.725 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (3, '2024-11-21', 2, 1891.33, 2, 45, 10);
# 2026-03-25 16:53:14.727 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (4, '2024-05-26', 3, 995.53, 9, 29, 5);
# 2026-03-25 16:53:14.728 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (5, '2024-04-15', 2, 1568.9, 13, 38, 10);
# 2026-03-25 16:53:14.730 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (6, '2024-01-02', 1, 409.67, 6, 51, 4);
# 2026-03-25 16:53:14.732 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (7, '2024-01-30', 3, 710.83, 11, 44, 5);
# 2026-03-25 16:53:14.736 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (8, '2024-06-04', 3, 716.6, 13, 9, 3);
# 2026-03-25 16:53:14.738 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (9, '2024-05-14', 2, 1270.16, 14, 16, 1);
# 2026-03-25 16:53:14.741 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (10, '2024-11-29', 1, 833.0, 17, 70, 7);
# 2026-03-25 16:53:14.743 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (11, '2024-06-04', 2, 1601.47, 22, 35, 3);
# 2026-03-25 16:53:14.745 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (12, '2024-10-31', 3, 737.22, 12, 73, 1);
# 2026-03-25 16:53:14.748 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (13, '2024-08-26', 1, 2351.02, 20, 2, 10);
# 2026-03-25 16:53:14.750 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (14, '2024-03-17', 1, 2021.4, 20, 2, 10);
# 2026-03-25 16:53:14.753 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (15, '2024-03-14', 1, 1679.3, 13, 18, 3);
# 2026-03-25 16:53:14.755 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (16, '2024-02-23', 2, 908.91, 13, 70, 3);
# 2026-03-25 16:53:14.756 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (17, '2024-02-15', 3, 960.08, 7, 41, 10);
# 2026-03-25 16:53:14.758 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (18, '2024-11-08', 3, 2325.63, 1, 30, 6);
# 2026-03-25 16:53:14.759 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (19, '2024-09-04', 3, 1153.07, 16, 56, 1);
# 2026-03-25 16:53:14.761 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (20, '2024-06-03', 3, 1176.22, 8, 20, 2);
# 2026-03-25 16:53:14.763 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (21, '2024-01-08', 1, 2371.63, 25, 30, 8);
# 2026-03-25 16:53:14.765 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (22, '2024-04-26', 1, 1447.26, 6, 42, 10);
# 2026-03-25 16:53:14.769 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (23, '2024-11-08', 2, 1478.32, 22, 11, 5);
# 2026-03-25 16:53:14.771 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (24, '2024-05-16', 1, 979.58, 2, 40, 1);
# 2026-03-25 16:53:14.773 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (25, '2024-01-24', 1, 958.17, 16, 50, 10);
# 2026-03-25 16:53:14.775 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (26, '2024-02-23', 3, 715.96, 24, 46, 7);
# 2026-03-25 16:53:14.776 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (27, '2024-11-21', 3, 1223.66, 10, 55, 1);
# 2026-03-25 16:53:14.778 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (28, '2024-03-28', 3, 819.13, 25, 65, 6);
# 2026-03-25 16:53:14.780 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (29, '2024-11-16', 3, 1787.71, 11, 48, 10);
# 2026-03-25 16:53:14.781 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (30, '2024-03-21', 1, 1602.8, 15, 37, 8);
# 2026-03-25 16:53:14.782 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (31, '2024-12-07', 2, 1475.6, 12, 15, 10);
# 2026-03-25 16:53:14.785 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (32, '2024-11-10', 2, 1479.54, 4, 3, 2);
# 2026-03-25 16:53:14.787 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (33, '2024-07-02', 1, 906.15, 22, 65, 7);
# 2026-03-25 16:53:14.789 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (34, '2024-02-12', 2, 866.86, 2, 29, 10);
# 2026-03-25 16:53:14.791 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (35, '2024-03-17', 2, 904.81, 9, 64, 10);
# 2026-03-25 16:53:14.792 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (36, '2024-05-03', 2, 975.78, 19, 62, 2);
# 2026-03-25 16:53:14.794 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (37, '2024-11-12', 1, 1287.08, 2, 53, 3);
# 2026-03-25 16:53:14.795 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (38, '2024-03-29', 1, 679.84, 21, 46, 4);
# 2026-03-25 16:53:14.797 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (39, '2024-10-04', 2, 1331.43, 22, 22, 1);
# 2026-03-25 16:53:14.800 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (40, '2024-09-28', 2, 878.72, 20, 65, 10);
# 2026-03-25 16:53:14.802 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (41, '2024-12-17', 2, 2593.29, 15, 74, 2);
# 2026-03-25 16:53:14.803 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (42, '2024-07-29', 3, 1344.18, 6, 43, 3);
# 2026-03-25 16:53:14.805 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (43, '2024-08-26', 3, 1191.2, 17, 5, 10);
# 2026-03-25 16:53:14.806 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (44, '2024-12-05', 2, 1492.91, 16, 14, 7);
# 2026-03-25 16:53:14.808 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (45, '2024-07-31', 2, 1201.16, 7, 1, 6);
# 2026-03-25 16:53:14.810 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (46, '2024-11-08', 2, 1435.86, 22, 36, 4);
# 2026-03-25 16:53:14.812 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (47, '2024-06-04', 2, 1584.12, 15, 33, 4);
# 2026-03-25 16:53:14.815 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (48, '2024-12-11', 3, 2181.1, 9, 2, 7);
# 2026-03-25 16:53:14.817 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (49, '2024-06-24', 2, 1770.41, 21, 67, 7);
# 2026-03-25 16:53:14.820 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (50, '2024-10-17', 3, 1339.98, 25, 22, 7);
# 2026-03-25 16:53:14.822 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (51, '2024-08-07', 3, 2204.33, 17, 48, 3);
# 2026-03-25 16:53:14.824 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (52, '2024-08-06', 2, 1157.31, 25, 50, 7);
# 2026-03-25 16:53:14.826 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (53, '2024-04-29', 2, 513.44, 5, 60, 1);
# 2026-03-25 16:53:14.827 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (54, '2024-07-05', 2, 1024.06, 11, 24, 10);
# 2026-03-25 16:53:14.829 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (55, '2024-01-23', 3, 2300.2, 23, 74, 4);
# 2026-03-25 16:53:14.831 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (56, '2024-04-17', 1, 1120.71, 14, 1, 6);
# 2026-03-25 16:53:14.834 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (57, '2024-07-31', 2, 1414.31, 17, 11, 1);
# 2026-03-25 16:53:14.836 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (58, '2024-03-08', 2, 888.91, 20, 65, 3);
# 2026-03-25 16:53:14.838 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (59, '2024-02-06', 1, 888.74, 25, 70, 4);
# 2026-03-25 16:53:14.840 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (60, '2024-03-20', 3, 1551.64, 12, 49, 10);
# 2026-03-25 16:53:14.841 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (61, '2024-07-10', 2, 1001.88, 11, 10, 7);
# 2026-03-25 16:53:14.843 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (62, '2024-02-11', 1, 2143.59, 18, 2, 9);
# 2026-03-25 16:53:14.844 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (63, '2024-10-02', 1, 1086.29, 20, 42, 10);
# 2026-03-25 16:53:14.846 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (64, '2024-10-13', 1, 1803.3, 6, 31, 5);
# 2026-03-25 16:53:14.848 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (65, '2024-07-26', 1, 1183.82, 6, 27, 6);
# 2026-03-25 16:53:14.850 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (66, '2024-06-21', 3, 1706.19, 10, 45, 7);
# 2026-03-25 16:53:14.852 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (67, '2024-09-27', 2, 1470.95, 21, 67, 7);
# 2026-03-25 16:53:14.854 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (68, '2024-02-24', 2, 2533.88, 18, 30, 4);
# 2026-03-25 16:53:14.855 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (69, '2024-05-16', 1, 902.11, 9, 60, 2);
# 2026-03-25 16:53:14.857 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (70, '2024-03-05', 3, 1335.81, 19, 36, 4);
# 2026-03-25 16:53:14.860 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (71, '2024-08-06', 2, 1427.89, 22, 15, 3);
# 2026-03-25 16:53:14.862 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (72, '2024-12-26', 2, 947.14, 19, 40, 1);
# 2026-03-25 16:53:14.864 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (73, '2024-02-23', 1, 737.85, 19, 9, 1);
# 2026-03-25 16:53:14.882 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (74, '2024-02-22', 1, 1882.01, 20, 48, 10);
# 2026-03-25 16:53:14.884 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (75, '2024-12-26', 2, 1539.79, 2, 13, 10);
# 2026-03-25 16:53:14.886 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (76, '2024-07-25', 2, 2070.23, 5, 31, 3);
# 2026-03-25 16:53:14.888 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (77, '2024-09-14', 1, 979.9, 8, 27, 2);
# 2026-03-25 16:53:14.890 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (78, '2024-12-14', 1, 900.25, 9, 8, 4);
# 2026-03-25 16:53:14.892 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (79, '2024-11-22', 1, 1913.9, 21, 6, 10);
# 2026-03-25 16:53:14.894 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (80, '2024-06-10', 1, 1069.47, 9, 68, 6);
# 2026-03-25 16:53:14.895 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (81, '2024-07-31', 2, 1979.46, 17, 26, 10);
# 2026-03-25 16:53:14.897 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (82, '2024-05-01', 1, 2100.03, 4, 48, 10);
# 2026-03-25 16:53:14.899 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (83, '2024-11-09', 3, 2091.09, 24, 71, 7);
# 2026-03-25 16:53:14.901 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (84, '2024-12-05', 2, 1274.1, 11, 61, 6);
# 2026-03-25 16:53:14.904 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (85, '2024-04-15', 3, 1570.91, 21, 25, 6);
# 2026-03-25 16:53:14.906 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (86, '2024-11-02', 3, 1099.63, 11, 61, 5);
# 2026-03-25 16:53:14.908 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (87, '2024-04-13', 2, 1846.94, 8, 6, 9);
# 2026-03-25 16:53:14.909 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (88, '2024-12-26', 3, 899.93, 16, 41, 6);
# 2026-03-25 16:53:14.911 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (89, '2024-09-18', 2, 2408.22, 24, 2, 4);
# 2026-03-25 16:53:14.914 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (90, '2024-12-25', 1, 849.96, 25, 62, 8);
# 2026-03-25 16:53:14.915 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (91, '2024-03-21', 1, 1467.33, 3, 45, 1);
# 2026-03-25 16:53:14.918 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (92, '2024-04-13', 1, 901.62, 7, 59, 7);
# 2026-03-25 16:53:14.921 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (93, '2024-08-28', 3, 2070.66, 23, 21, 4);
# 2026-03-25 16:53:14.922 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (94, '2024-08-05', 1, 1744.45, 7, 19, 2);
# 2026-03-25 16:53:14.924 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (95, '2024-02-26', 1, 834.66, 17, 41, 8);
# 2026-03-25 16:53:14.926 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (96, '2024-10-04', 2, 1519.47, 6, 37, 8);
# 2026-03-25 16:53:14.928 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (97, '2024-10-24', 2, 1665.68, 5, 14, 7);
# 2026-03-25 16:53:14.930 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (98, '2024-11-05', 2, 774.39, 16, 34, 8);
# 2026-03-25 16:53:14.932 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (99, '2024-12-17', 1, 1093.92, 15, 68, 7);
# 2026-03-25 16:53:14.934 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (100, '2024-02-24', 2, 993.97, 24, 27, 3);
# 2026-03-25 16:53:14.936 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (101, '2024-08-17', 3, 859.73, 20, 75, 2);
# 2026-03-25 16:53:14.938 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (102, '2024-07-19', 3, 2024.79, 16, 52, 5);
# 2026-03-25 16:53:14.940 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (103, '2024-10-17', 2, 771.99, 13, 34, 2);
# 2026-03-25 16:53:14.941 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (104, '2024-10-13', 1, 2117.44, 7, 6, 7);
# 2026-03-25 16:53:14.943 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (105, '2024-05-30', 1, 1256.66, 13, 16, 10);
# 2026-03-25 16:53:14.945 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (106, '2024-11-14', 1, 874.02, 15, 46, 9);
# 2026-03-25 16:53:14.947 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (107, '2024-02-03', 2, 1183.73, 22, 58, 2);
# 2026-03-25 16:53:14.949 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (108, '2024-02-08', 1, 1299.72, 6, 22, 1);
# 2026-03-25 16:53:14.950 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (109, '2024-01-08', 1, 1495.26, 1, 19, 5);
# 2026-03-25 16:53:14.952 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (110, '2024-01-11', 3, 1514.47, 11, 38, 9);
# 2026-03-25 16:53:14.954 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (111, '2024-12-07', 3, 937.96, 15, 62, 3);
# 2026-03-25 16:53:14.956 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (112, '2024-03-08', 3, 957.64, 15, 66, 5);
# 2026-03-25 16:53:14.958 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (113, '2024-03-01', 1, 1374.94, 6, 23, 5);
# 2026-03-25 16:53:14.959 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (114, '2024-11-11', 1, 2008.67, 21, 6, 9);
# 2026-03-25 16:53:14.960 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (115, '2024-07-13', 2, 1900.74, 12, 49, 10);
# 2026-03-25 16:53:14.962 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (116, '2024-06-25', 3, 1267.31, 12, 18, 3);
# 2026-03-25 16:53:14.963 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (117, '2024-03-17', 3, 1042.48, 1, 27, 3);
# 2026-03-25 16:53:14.965 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (118, '2024-09-18', 2, 1228.15, 9, 72, 5);
# 2026-03-25 16:53:14.966 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (119, '2024-04-16', 1, 1743.98, 19, 21, 6);
# 2026-03-25 16:53:14.968 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (120, '2024-05-18', 1, 854.88, 19, 4, 5);
# 2026-03-25 16:53:14.970 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (121, '2024-11-21', 2, 1314.19, 4, 58, 5);
# 2026-03-25 16:53:14.972 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (122, '2024-09-14', 2, 1107.82, 14, 56, 3);
# 2026-03-25 16:53:14.974 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (123, '2024-11-22', 3, 1266.21, 8, 16, 8);
# 2026-03-25 16:53:14.975 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (124, '2024-08-12', 1, 1159.21, 1, 22, 4);
# 2026-03-25 16:53:14.977 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (125, '2024-07-13', 2, 1078.42, 7, 50, 10);
# 2026-03-25 16:53:14.979 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (126, '2024-09-11', 1, 1757.01, 10, 49, 9);
# 2026-03-25 16:53:14.981 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (127, '2024-04-13', 1, 603.7, 3, 32, 3);
# 2026-03-25 16:53:14.983 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (128, '2024-06-08', 2, 959.83, 12, 54, 8);
# 2026-03-25 16:53:14.984 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (129, '2024-12-14', 1, 1190.31, 10, 11, 10);
# 2026-03-25 16:53:14.986 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (130, '2024-12-30', 3, 864.1, 10, 60, 2);
# 2026-03-25 16:53:14.988 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (131, '2024-10-30', 3, 1172.91, 17, 58, 2);
# 2026-03-25 16:53:14.989 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (132, '2024-10-23', 3, 1576.46, 24, 35, 1);
# 2026-03-25 16:53:14.991 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (133, '2024-03-29', 2, 935.26, 15, 27, 7);
# 2026-03-25 16:53:14.993 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (134, '2024-02-01', 3, 896.98, 9, 66, 6);
# 2026-03-25 16:53:14.995 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (135, '2024-08-12', 1, 1456.04, 9, 35, 8);
# 2026-03-25 16:53:14.996 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (136, '2024-01-28', 1, 692.55, 11, 9, 5);
# 2026-03-25 16:53:14.998 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (137, '2024-07-14', 3, 1589.36, 24, 13, 4);
# 2026-03-25 16:53:15.000 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (138, '2024-01-21', 1, 851.06, 3, 62, 8);
# 2026-03-25 16:53:15.002 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (139, '2024-08-14', 1, 1547.76, 21, 63, 1);
# 2026-03-25 16:53:15.003 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (140, '2024-06-06', 3, 1216.78, 3, 72, 4);
# 2026-03-25 16:53:15.005 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (141, '2024-09-29', 2, 994.34, 6, 29, 5);
# 2026-03-25 16:53:15.007 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (142, '2024-11-03', 1, 1793.75, 15, 14, 4);
# 2026-03-25 16:53:15.008 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (143, '2024-05-21', 1, 1501.82, 24, 38, 8);
# 2026-03-25 16:53:15.010 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (144, '2024-10-28', 1, 1542.41, 20, 63, 2);
# 2026-03-25 16:53:15.012 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (145, '2024-11-14', 2, 1356.79, 7, 11, 10);
# 2026-03-25 16:53:15.013 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (146, '2024-07-02', 1, 902.77, 14, 10, 4);
# 2026-03-25 16:53:15.015 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (147, '2024-02-14', 3, 1159.8, 6, 1, 8);
# 2026-03-25 16:53:15.017 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (148, '2024-09-16', 3, 1075.78, 19, 68, 7);
# 2026-03-25 16:53:15.019 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (149, '2024-04-27', 3, 1581.13, 9, 38, 3);
# 2026-03-25 16:53:15.022 | WARNING  | __main__:<module>:176 - FAILED: INSERT INTO Fiets_Verkoop VALUES (150, '2024-11-21', 2, 911.0, 8, 47, 2);

# %% [markdown]
# Toevoegen van een extra rij

# %%
# We voegen een extra rij toe aan de Operationele Database (Fietsverkoop)

# We maken eerst de connectie met de Operationele Database
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_2_Fietsverkoop.db')
source_cursor = source_conn.cursor()

# We voegen een extra rij toe aan het tabel van Fiets.

sql_insert = """
INSERT INTO Fiets 
VALUES (1500, 'Stadsfiets', 'Gazelle', 'Classic', 599.99, 400.00, 'Zwart', 1)
"""

source_cursor.execute(sql_insert)
source_conn.commit()

source_cursor.close()
source_conn.close()

# %% [markdown]
# Wijzigen van de extra rij

# %%
# We wijzigen deze rij in de Operationele Database.

# We maken eerst de connectie met de Operationele Database
source_conn = source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_2_Fietsverkoop.db')
source_cursor = source_conn.cursor()

# We wijzigen de rij van kleur zwart naar kleur blauw
sql_update = """
UPDATE Fiets
SET kleur = 'Blauw'
WHERE fietsnr = 1500
"""

source_cursor.execute(sql_update)
source_conn.commit()

source_cursor.close()
source_conn.close()

# %% [markdown]
# Verwijderen van de extra rij

# %%
# We verwijderen de rij in de Operationele Database.

# We maken eerst de connectie met de Operationele Database
source_conn = source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_2_Fietsverkoop.db')
source_cursor = source_conn.cursor()

# We deleten de fiets met PK = 1500
sql_delete = """
DELETE FROM Fiets
WHERE fietsnr = 1500
"""

source_cursor.execute(sql_delete)
source_conn.commit()

source_cursor.close()
source_conn.close()
