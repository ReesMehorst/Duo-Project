# %%
import pandas as pd
import sqlite3
from loguru import logger

doel_conn = sqlite3.connect('../../BikeToDrive_V3_OLTP.db')
doel_cursor = doel_conn.cursor()

# %% [markdown]
# Accessoire_Inkoop

# %% [markdown]
# Accessoire_Verkoop

# %% [markdown]
# Onderhoud

# %% [markdown]
# Fiets_Inkoop

# %% [markdown]
# Fiets_Verkoop
