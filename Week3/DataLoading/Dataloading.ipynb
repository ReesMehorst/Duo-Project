# %%
import pandas as pd
import sqlite3
from loguru import logger

logger.add("logs/dataloading_sdm.log", rotation="10 MB", level="INFO")
doel_conn = sqlite3.connect('../../Source Data Model/BikeToDrive_V3_OLTP.db', timeout=30)
doel_cursor = doel_conn.cursor()

# %% [markdown]
# Accessoire_Inkoop

# %%
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_4_Accessoire_Inkoop.db')
source_cursor = source_conn.cursor()

logger.info("Start dataloading Accessoire_Inkoop")

try:
    # Delete voor Full-Refresh
    alle_tabellen = [
        'Accessoire_Inkoop_Leverancier',
        'Accessoire_Inkoop_Accessoire',
        'Accessoire_Inkoop'
    ][::-1] # We draaien de volgorde van de tabellen om.

    # We deleten alles van onze bestaande OLTP database
    for tabel in alle_tabellen:
        try:
            doel_cursor.execute(f"DELETE FROM {tabel};")
            logger.info(f"Tabel geleegd: {tabel}")
        except Exception as e:
            logger.error(f"FAILED DELETE on {tabel}: {e}")

    doel_conn.commit()
    logger.info("Delete afgerond") # loggen succes delete

    # Fetchen data van leveranciers en loggen hiervan
    source_cursor.execute("SELECT * FROM Leverancier")
    leveranciers = source_cursor.fetchall()
    logger.info(f"{len(leveranciers)} leveranciers opgehaald")

    for row in leveranciers:
        try:
            doel_cursor.execute(
                "INSERT INTO Accessoire_Inkoop_Leverancier VALUES (?, ?, ?, ?)", # id, naam, adres, woonplaats
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Leverancier: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(leveranciers)} leveranciers geladen")

    # Fetchen data van accessoires en loggen hiervan
    source_cursor.execute("SELECT * FROM Accessoire")
    accessoires = source_cursor.fetchall()
    logger.info(f"{len(accessoires)} accessoires opgehaald")

    for row in accessoires:
        try:
            doel_cursor.execute(
                "INSERT INTO Accessoire_Inkoop_Accessoire VALUES (?, ?, ?, ?, ?, ?)", # id, naam, standaardprijs, inkoopprijs, soort, leverancier
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Accessoire: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(accessoires)} accessoires geladen")

    # Fetchen data van inkoop en loggen hiervan
    source_cursor.execute("SELECT * FROM Accessoire_Inkoop")
    inkoop = source_cursor.fetchall()
    logger.info(f"{len(inkoop)} inkoop opgehaald")

    for row in inkoop:
        try:
            doel_cursor.execute(
                "INSERT INTO Accessoire_Inkoop VALUES (?, ?, ?, ?, ?)", # id, maand, jaar, aantal, accessoire
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Accessoire_Inkoop: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(inkoop)} inkoopregels geladen")

    logger.info("dataloading succesvol afgerond")

except Exception as e:
    logger.critical(f"dataloading volledig gefaald: {e}")

finally:
    # sluiten connecties
    source_cursor.close()
    source_conn.close()

    logger.info("Database connecties gesloten")
# Out:
# 2026-04-19 12:35:10.608 | INFO     | __main__:<module>:4 - Start dataloading Accessoire_Inkoop
# 2026-04-19 12:35:10.616 | INFO     | __main__:<module>:18 - Tabel geleegd: Accessoire_Inkoop
# 2026-04-19 12:35:10.619 | INFO     | __main__:<module>:18 - Tabel geleegd: Accessoire_Inkoop_Accessoire
# 2026-04-19 12:35:10.622 | INFO     | __main__:<module>:18 - Tabel geleegd: Accessoire_Inkoop_Leverancier
# 2026-04-19 12:35:10.630 | INFO     | __main__:<module>:23 - Delete afgerond
# 2026-04-19 12:35:10.633 | INFO     | __main__:<module>:28 - 5 leveranciers opgehaald
# 2026-04-19 12:35:10.642 | INFO     | __main__:<module>:40 - 5 leveranciers geladen
# 2026-04-19 12:35:10.645 | INFO     | __main__:<module>:45 - 13 accessoires opgehaald
# 2026-04-19 12:35:10.655 | INFO     | __main__:<module>:57 - 13 accessoires geladen
# 2026-04-19 12:35:10.658 | INFO     | __main__:<module>:62 - 50 inkoop opgehaald
# 2026-04-19 12:35:10.667 | INFO     | __main__:<module>:74 - 50 inkoopregels geladen
# 2026-04-19 12:35:10.669 | INFO     | __main__:<module>:76 - dataloading succesvol afgerond
# 2026-04-19 12:35:10.672 | INFO     | __main__:<module>:86 - Database connecties gesloten

# %% [markdown]
# Accessoire_Verkoop

# %%
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_1_Accessoireverkoop.db')
source_cursor = source_conn.cursor()

try:
    logger.info("Start dataloading Accessoire_Verkoop")
    # Delete voor Full Refresh
    alle_tabellen = [
        'Accessoire_Verkoop',
        'Accessoire_Verkoop_Monteur',
        'Accessoire_Verkoop_Filiaal',
        'Accessoire_Verkoop_Klant',
        'Accessoire_Verkoop_Accessoire',
        'Accessoire_Verkoop_Leverancier'
    ][::-1] # We draaien de volgorde van de tabellen om.

    for tabel in alle_tabellen:
        try:
            doel_cursor.execute(f"DELETE FROM {tabel};")
            logger.info(f"Tabel geleegd: {tabel}")
        except Exception as e:
            logger.error(f"FAILED DELETE on {tabel}: {e}")

    doel_conn.commit()
    logger.info("Delete afgerond") # loggen succes delete

    # Fetchen data van leveranciers en loggen hiervan
    source_cursor.execute("SELECT * FROM Leverancier")
    leveranciers = source_cursor.fetchall()
    logger.info(f"{len(leveranciers)} leveranciers opgehaald")

    for row in leveranciers:
        try:
            doel_cursor.execute(
                "INSERT INTO Accessoire_Verkoop_Leverancier VALUES (?, ?, ?, ?)", # id, naam, adres, woonplaats
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Leverancier: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(leveranciers)} leveranciers geladen")
    
    # Fetchen data van accessoires en loggen hiervan
    source_cursor.execute("SELECT * FROM Accessoire")
    accessoires = source_cursor.fetchall()
    logger.info(f"{len(accessoires)} accessoires opgehaald")

    for row in accessoires:
        try:
            doel_cursor.execute(
                "INSERT INTO Accessoire_Verkoop_Accessoire VALUES (?, ?, ?, ?, ?, ?)", # id, naam, standaardprijs, inkoopprijs, soort, leverancier
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Accessoire: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(accessoires)} accessoires geladen")

    # Fetchen data van klanten en loggen hiervan
    source_cursor.execute("SELECT * FROM Klant")
    Klant = source_cursor.fetchall()
    logger.info(f"{len(Klant)} klanten opgehaald")

    for row in Klant:
        try:
            doel_cursor.execute(
                "INSERT INTO Accessoire_Verkoop_Klant VALUES (?, ?, ?, ?, ?, ?)", # id, naam, adres, woonplaats, geslacht, geboortedatum
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Klant: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(Klant)} klanten geladen")

    # Fetchen data van filialen en loggen hiervan
    source_cursor.execute("SELECT * FROM Filiaal")
    Filiaal = source_cursor.fetchall()
    logger.info(f"{len(Filiaal)} filialen opgehaald")

    for row in Filiaal:
        try:
            doel_cursor.execute(
                "INSERT INTO Accessoire_Verkoop_Filiaal VALUES (?, ?, ?, ?)", # id, naam, adres, provincie
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Filiaal: {row} ({e})")
    
    doel_conn.commit()
    logger.info(f"{len(Filiaal)} filialen geladen")

    # Fetchen data van monteurs en loggen hiervan
    source_cursor.execute("SELECT * FROM Monteur")
    Monteur = source_cursor.fetchall()
    logger.info(f"{len(Monteur)} monteurs opgehaald")

    for row in Monteur:
        try:
            doel_cursor.execute(
                "INSERT INTO Accessoire_Verkoop_Monteur VALUES (?, ?, ?, ?, ?)", # id, naam, woonplaats, uurloon, filiaal
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Monteur: {row} ({e})")
    
    doel_conn.commit()
    logger.info(f"{len(Monteur)} monteurs geladen")
    
    # Fetchen data van verkoop en loggen hiervan
    source_cursor.execute("SELECT * FROM Accessoire_Verkoop")
    Accessoire_Verkoop = source_cursor.fetchall()
    logger.info(f"{len(Accessoire_Verkoop)} verkoop opgehaald")

    for row in Accessoire_Verkoop:
        try:
            doel_cursor.execute(
                "INSERT INTO Accessoire_Verkoop VALUES (?, ?, ?, ?, ?, ?, ?)", # id, datum, aantal, verkoopprijs, klant, accessoire, monteur
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Accessoire_Verkoop: {row} ({e})")
    
    doel_conn.commit()
    logger.info(f"{len(Accessoire_Verkoop)} verkoop geladen")
            
except Exception as e:
    logger.critical(f"dataloading volledig gefaald: {e}")

finally:
    doel_conn.commit()
    source_cursor.close()
    source_conn.close()

    logger.info("Database connecties gesloten")
# Out:
# 2026-04-19 12:35:10.702 | INFO     | __main__:<module>:5 - Start dataloading Accessoire_Verkoop
# 2026-04-19 12:35:10.704 | INFO     | __main__:<module>:19 - Tabel geleegd: Accessoire_Verkoop_Leverancier
# 2026-04-19 12:35:10.706 | INFO     | __main__:<module>:19 - Tabel geleegd: Accessoire_Verkoop_Accessoire
# 2026-04-19 12:35:10.708 | INFO     | __main__:<module>:19 - Tabel geleegd: Accessoire_Verkoop_Klant
# 2026-04-19 12:35:10.710 | INFO     | __main__:<module>:19 - Tabel geleegd: Accessoire_Verkoop_Filiaal
# 2026-04-19 12:35:10.712 | INFO     | __main__:<module>:19 - Tabel geleegd: Accessoire_Verkoop_Monteur
# 2026-04-19 12:35:10.714 | INFO     | __main__:<module>:19 - Tabel geleegd: Accessoire_Verkoop
# 2026-04-19 12:35:10.719 | INFO     | __main__:<module>:24 - Delete afgerond
# 2026-04-19 12:35:10.723 | INFO     | __main__:<module>:29 - 5 leveranciers opgehaald
# 2026-04-19 12:35:10.731 | INFO     | __main__:<module>:41 - 5 leveranciers geladen
# 2026-04-19 12:35:10.733 | INFO     | __main__:<module>:46 - 10 accessoires opgehaald
# 2026-04-19 12:35:10.741 | INFO     | __main__:<module>:58 - 10 accessoires geladen
# 2026-04-19 12:35:10.743 | INFO     | __main__:<module>:63 - 20 klanten opgehaald
# 2026-04-19 12:35:10.751 | INFO     | __main__:<module>:75 - 20 klanten geladen
# 2026-04-19 12:35:10.753 | INFO     | __main__:<module>:80 - 4 filialen opgehaald
# 2026-04-19 12:35:10.761 | INFO     | __main__:<module>:92 - 4 filialen geladen
# 2026-04-19 12:35:10.762 | INFO     | __main__:<module>:97 - 10 monteurs opgehaald
# 2026-04-19 12:35:10.768 | INFO     | __main__:<module>:109 - 10 monteurs geladen
# 2026-04-19 12:35:10.770 | INFO     | __main__:<module>:114 - 100 verkoop opgehaald
# 2026-04-19 12:35:10.776 | INFO     | __main__:<module>:126 - 100 verkoop geladen
# 2026-04-19 12:35:10.777 | INFO     | __main__:<module>:136 - Database connecties gesloten

# %% [markdown]
# Onderhoud

# %%
# We maken eerst connectie met de bron.
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_3_Onderhoud.db')
source_cursor = source_conn.cursor()

# Lijst met alle tabellen die geleegd moeten worden.
try:
    logger.info("Start dataloading Onderhoud")
    alle_tabellen = [
        'Onderhoud_Fabrikant',
        'Onderhoud_Filiaal',
        'Onderhoud_Fiets',
        'Onderhoud_Monteur',
        'Onderhoud'
    ][::-1] # We draaien de volgorde van de tabellen om.

    for tabel in alle_tabellen:
        try:
            doel_cursor.execute(f"DELETE FROM {tabel};")
            logger.info(f"Tabel geleegd: {tabel}")
        except Exception as e:
            logger.error(f"FAILED DELETE on {tabel}: {e}")

    doel_conn.commit()
    logger.info("Delete afgerond") # loggen succes delete

    # 1. Onderhoud_Fabrikant
    source_cursor.execute("SELECT * FROM Fabrikant")
    Fabrikant = source_cursor.fetchall()
    logger.info(f"{len(Fabrikant)} fabrikanten opgehaald")

    for row in Fabrikant:
        try:
            doel_cursor.execute(
                "INSERT INTO Onderhoud_Fabrikant VALUES (?, ?, ?, ?)", # id, naam, adres, plaats
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Fabrikant: {row} ({e})")
        
    doel_conn.commit()
    logger.info(f"{len(Fabrikant)} fabrikanten geladen")

    # 2. Onderhoud_Fiets
    source_cursor.execute("SELECT * FROM Fiets")
    Fiets = source_cursor.fetchall()
    logger.info(f"{len(Fiets)} fietsen opgehaald")

    for row in Fiets:
        try:
            doel_cursor.execute(
                "INSERT INTO Onderhoud_Fiets VALUES (?, ?, ?, ?, ?, ?, ?, ?)", # id, soort, merk, type, standaardprijs, inkoopprijs, kleur, fabrikant
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Fiets: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(Fiets)} fietsen geladen")

    # 3. Onderhoud_Filiaal
    source_cursor.execute("SELECT * FROM Filiaal")
    Filiaal = source_cursor.fetchall()
    logger.info(f"{len(Filiaal)} filialen opgehaald")

    for row in Filiaal:
        try:
            doel_cursor.execute(
                "INSERT INTO Onderhoud_Filiaal VALUES (?, ?, ?, ?)", # id, naam, adres, provincie
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Filiaal: {row} ({e})")
        
    doel_conn.commit()
    logger.info(f"{len(Filiaal)} filialen geladen")
    
    # 4. Onderhoud_Monteur
    source_cursor.execute("SELECT * FROM Monteur")
    Monteur = source_cursor.fetchall()
    logger.info(f"{len(Monteur)} monteurs opgehaald")

    for row in Monteur:
        try:
            doel_cursor.execute(
                "INSERT INTO Onderhoud_Monteur VALUES (?, ?, ?, ?, ?)", # id, naam, woonplaats, uurloon, filiaal
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Monteur: {row} ({e})")
        
    doel_conn.commit()
    logger.info(f"{len(Monteur)} monteurs geladen")

    # 5. Onderhoud
    source_cursor.execute("SELECT * FROM Onderhoud")
    Onderhoud = source_cursor.fetchall()
    logger.info(f"{len(Onderhoud)} onderhoud opgehaald")

    for row in Onderhoud:
        try:
            doel_cursor.execute(
                "INSERT INTO Onderhoud VALUES (?, ?, ?, ?, ?, ?)", # id, datum, starttijd, eindtijd, fiets, monteur
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Onderhoud: {row} ({e})")
    
    doel_conn.commit()
    logger.info(f"{len(Onderhoud)} onderhoud geladen")

except Exception as e:
    logger.critical(f"dataloading volledig gefaald: {e}")

finally:
    source_cursor.close()
    source_conn.close()

    logger.info("Database connecties gesloten")
# Out:
# 2026-04-19 12:35:10.798 | INFO     | __main__:<module>:7 - Start dataloading Onderhoud
# 2026-04-19 12:35:10.802 | INFO     | __main__:<module>:19 - Tabel geleegd: Onderhoud
# 2026-04-19 12:35:10.804 | INFO     | __main__:<module>:19 - Tabel geleegd: Onderhoud_Monteur
# 2026-04-19 12:35:10.806 | INFO     | __main__:<module>:19 - Tabel geleegd: Onderhoud_Fiets
# 2026-04-19 12:35:10.808 | INFO     | __main__:<module>:19 - Tabel geleegd: Onderhoud_Filiaal
# 2026-04-19 12:35:10.809 | INFO     | __main__:<module>:19 - Tabel geleegd: Onderhoud_Fabrikant
# 2026-04-19 12:35:10.814 | INFO     | __main__:<module>:24 - Delete afgerond
# 2026-04-19 12:35:10.815 | INFO     | __main__:<module>:29 - 11 fabrikanten opgehaald
# 2026-04-19 12:35:10.820 | INFO     | __main__:<module>:41 - 11 fabrikanten geladen
# 2026-04-19 12:35:10.822 | INFO     | __main__:<module>:46 - 30 fietsen opgehaald
# 2026-04-19 12:35:10.828 | INFO     | __main__:<module>:58 - 30 fietsen geladen
# 2026-04-19 12:35:10.830 | INFO     | __main__:<module>:63 - 5 filialen opgehaald
# 2026-04-19 12:35:10.837 | INFO     | __main__:<module>:75 - 5 filialen geladen
# 2026-04-19 12:35:10.838 | INFO     | __main__:<module>:80 - 15 monteurs opgehaald
# 2026-04-19 12:35:10.844 | INFO     | __main__:<module>:92 - 15 monteurs geladen
# 2026-04-19 12:35:10.846 | INFO     | __main__:<module>:97 - 50 onderhoud opgehaald
# 2026-04-19 12:35:10.851 | INFO     | __main__:<module>:109 - 50 onderhoud geladen
# 2026-04-19 12:35:10.852 | INFO     | __main__:<module>:118 - Database connecties gesloten

# %% [markdown]
# Fiets_Inkoop

# %%
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_5_Fiets_Inkoop.db')
source_cursor = source_conn.cursor()

# Lijst met alle tabellen die geleegd moeten worden.
try:
    logger.info("Start dataloading Fiets inkoop")
    alle_tabellen = [
        'Fiets_Inkoop',
        'Fiets_Inkoop_Fiets',
        'Fiets_Inkoop_Fabrikant',
    ][::-1] # We draaien de volgorde van de tabellen om.
    
    for tabel in alle_tabellen:
        try:
            doel_cursor.execute(f"DELETE FROM {tabel};")
            logger.info(f"Tabel geleegd: {tabel}")
        except Exception as e:
            logger.error(f"FAILED DELETE on {tabel}: {e}")

    doel_conn.commit()
    logger.info("Delete afgerond") # loggen succes delete

    source_cursor.execute("SELECT * FROM Fabrikant")
    Fabrikant = source_cursor.fetchall()
    logger.info(f"{len(Fabrikant)} fabrikanten opgehaald")

    for row in Fabrikant:
        try:
            doel_cursor.execute(
                "INSERT INTO Fiets_Inkoop_Fabrikant VALUES (?, ?, ?, ?)", # id, naam, adres, plaats
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Fabrikant: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(Fabrikant)} fabrikanten geladen")

    # Fetchen data van fietsen en loggen hiervan
    source_cursor.execute("SELECT * FROM Fiets")
    Fiets = source_cursor.fetchall()
    logger.info(f"{len(Fiets)} fietsen opgehaald")

    for row in Fiets:
        try:
            doel_cursor.execute(
                "INSERT INTO Fiets_Inkoop_Fiets VALUES (?, ?, ?, ?, ?, ?, ?, ?)", # id, soort, merk, type, standaardprijs, inkoopprijs, kleur, fabrikant
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Fiets: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(Fiets)} fietsen geladen")

    # Fetchen data van inkoop en loggen hiervan
    source_cursor.execute("SELECT * FROM Fiets_Inkoop")
    Fiets_Inkoop = source_cursor.fetchall()
    logger.info(f"{len(Fiets_Inkoop)} inkoop opgehaald")
    for row in Fiets_Inkoop:
        try:
            doel_cursor.execute(
                "INSERT INTO Fiets_Inkoop VALUES (?, ?, ?, ?, ?)", # id, maand, jaar, aantal, fiets
                row
            )
        except Exception as e:
            logger.error(f"Insert failed Fiets_Inkoop: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(Fiets_Inkoop)} inkoop geladen")

except Exception as e:
    logger.error(f"dataloading volledig gefaald: {e}")

finally:
    doel_conn.commit()
    source_cursor.close()
    source_conn.close()

    logger.info("Database connecties gesloten")
# Out:
# 2026-04-19 12:35:10.872 | INFO     | __main__:<module>:6 - Start dataloading Fiets inkoop
# 2026-04-19 12:35:10.876 | INFO     | __main__:<module>:16 - Tabel geleegd: Fiets_Inkoop_Fabrikant
# 2026-04-19 12:35:10.879 | INFO     | __main__:<module>:16 - Tabel geleegd: Fiets_Inkoop_Fiets
# 2026-04-19 12:35:10.881 | INFO     | __main__:<module>:16 - Tabel geleegd: Fiets_Inkoop
# 2026-04-19 12:35:10.888 | INFO     | __main__:<module>:21 - Delete afgerond
# 2026-04-19 12:35:10.891 | INFO     | __main__:<module>:25 - 10 fabrikanten opgehaald
# 2026-04-19 12:35:10.897 | INFO     | __main__:<module>:37 - 10 fabrikanten geladen
# 2026-04-19 12:35:10.899 | INFO     | __main__:<module>:42 - 75 fietsen opgehaald
# 2026-04-19 12:35:10.905 | INFO     | __main__:<module>:54 - 75 fietsen geladen
# 2026-04-19 12:35:10.906 | INFO     | __main__:<module>:59 - 100 inkoop opgehaald
# 2026-04-19 12:35:10.912 | INFO     | __main__:<module>:70 - 100 inkoop geladen
# 2026-04-19 12:35:10.913 | INFO     | __main__:<module>:80 - Database connecties gesloten

# %% [markdown]
# Fiets_Verkoop

# %%
# We maken eerst connectie met de bron.
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_2_Fietsverkoop.db')
source_cursor = source_conn.cursor()

# Lijst met alle tabellen die geleegd moeten worden.

try:
    
    logger.info("Start Data Loading Fietsverkoop")
    alle_tabellen = [
        'Fiets_Verkoop_Fabrikant',
        'Fiets_Verkoop_Filiaal',
        'Fiets_Verkoop_Fiets',
        'Fiets_Verkoop_Monteur',
        'Fiets_Verkoop_Klant',
        'Fiets_Verkoop'
    ][::-1] # We draaien de volgorde om.

    # We deleten alles van onze bestaande OLTP database
    for tabel in alle_tabellen:
        try:
            doel_cursor.execute(f"DELETE FROM {tabel}")
            logger.info(f"Tabel geleegd: {tabel}")
        except Exception as e:
            logger.error(f"FAILED DELETE on {tabel}: {e}")

    # Commit na delete
    doel_conn.commit()
    logger.info("Delete afgerond") # loggen succes delete

    # De SQL Query die alles selecteert vanuit de Operationele Database.
    # We gaan eerst het tabel Fabrikant inserten in onze OLTP.
    source_cursor.execute("SELECT * FROM Fabrikant")
    Fabrikant = source_cursor.fetchall()
    logger.info(f"{len(Fabrikant)} fabrikanten opgehaald")

    # 1. Fiets_Verkoop_Fabrikant
    for row in Fabrikant:
            try:
                doel_cursor.execute("INSERT INTO Fiets_Verkoop_Fabrikant VALUES (?, ?, ?, ?)", row) # id,  naam,  adres, plaats
            except Exception as e:
                logger.error(f"Insert failed Fiets_Verkoop_Fabrikant: {row} ({e})")
            
        
    doel_conn.commit()
    logger.info(f"{len(Fabrikant)} fabrikanten geladen")

    # 2. Fiets
    source_cursor.execute("SELECT * FROM Fiets")
    Fiets = source_cursor.fetchall()
    logger.info(f"{len(Fiets)} fietsen opgehaald")

    for row in Fiets:
        try:
            doel_cursor.execute("INSERT INTO Fiets_Verkoop_Fiets VALUES (?, ?, ?, ?, ?, ?, ?, ?)", row) # id, soort, merk, type, standaardprijs, inkoopprijs, kleur, fabrikant
        except Exception as e:
            logger.error(f"Insert failed Fiets_Verkoop_Fiets: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(Fiets)} fietsen geladen")

    # 3. Filiaal
    source_cursor.execute("SELECT * FROM Filiaal")
    Filiaal = source_cursor.fetchall()
    logger.info(f"{len(Filiaal)} filialen opgehaald")

    for row in Filiaal:
        try:
            doel_cursor.execute("INSERT INTO Fiets_Verkoop_Filiaal VALUES (?, ?, ?, ?)", row) # id, naam, adres, provincie
        except Exception as e:
            logger.error(f"Insert failed Fiets_Verkoop_Filiaal: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(Filiaal)} filialen geladen")

    # 4. Monteur
    source_cursor.execute("SELECT * FROM Monteur")
    Monteur = source_cursor.fetchall()
    logger.info(f"{len(Monteur)} monteurs opgehaald")

    for row in Monteur:
        try:
            doel_cursor.execute("INSERT INTO Fiets_Verkoop_Monteur VALUES (?, ?, ?, ?, ?)", row) # id, naam, woonplaats, uurloon, filiaal
        except Exception as e:
            logger.error(f"Insert failed Fiets_Verkoop_Monteur: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(Monteur)} monteurs geladen")

    # 5. Klant
    source_cursor.execute("SELECT * FROM Klant")
    Klant = source_cursor.fetchall()
    logger.info(f"{len(Klant)} klanten opgehaald")

    for row in Klant:
        try:
            doel_cursor.execute("INSERT INTO Fiets_Verkoop_Klant VALUES (?, ?, ?, ?, ?, ?)", row) # id, naam, adres, woonplaats, geslacht, geboortedatum
        except Exception as e:
            logger.error(f"Insert failed Fiets_Verkoop_Klant: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(Klant)} klanten geladen")

    # 6. Verkoop
    source_cursor.execute("SELECT * FROM Fiets_Verkoop")
    Verkoop = source_cursor.fetchall()
    logger.info(f"{len(Verkoop)} verkoop opgehaald")

    for row in Verkoop:
        try:
            doel_cursor.execute("INSERT INTO Fiets_Verkoop VALUES (?, ?, ?, ?, ?, ?, ?)", row) # id, datum, aantal, verkoopprijs, klant, fiets, monteur
        except Exception as e:
            logger.error(f"Insert failed Fiets_Verkoop: {row} ({e})")

    doel_conn.commit()
    logger.info(f"{len(Verkoop)} verkoop geladen")

except Exception as e:
    logger.critical(f"dataloading volledig gefaald: {e}")


# We committen onze gewijzigde acties.
finally:
    doel_conn.commit()
    source_cursor.close()
    source_conn.close()

logger.info("Database connecties gesloten")
# Out:
# 2026-04-19 12:35:10.936 | INFO     | __main__:<module>:9 - Start Data Loading Fietsverkoop
# 2026-04-19 12:35:10.942 | INFO     | __main__:<module>:23 - Tabel geleegd: Fiets_Verkoop
# 2026-04-19 12:35:10.945 | INFO     | __main__:<module>:23 - Tabel geleegd: Fiets_Verkoop_Klant
# 2026-04-19 12:35:10.947 | INFO     | __main__:<module>:23 - Tabel geleegd: Fiets_Verkoop_Monteur
# 2026-04-19 12:35:10.949 | INFO     | __main__:<module>:23 - Tabel geleegd: Fiets_Verkoop_Fiets
# 2026-04-19 12:35:10.951 | INFO     | __main__:<module>:23 - Tabel geleegd: Fiets_Verkoop_Filiaal
# 2026-04-19 12:35:10.952 | INFO     | __main__:<module>:23 - Tabel geleegd: Fiets_Verkoop_Fabrikant
# 2026-04-19 12:35:10.958 | INFO     | __main__:<module>:29 - Delete afgerond
# 2026-04-19 12:35:10.961 | INFO     | __main__:<module>:35 - 10 fabrikanten opgehaald
# 2026-04-19 12:35:10.967 | INFO     | __main__:<module>:46 - 10 fabrikanten geladen
# 2026-04-19 12:35:10.969 | INFO     | __main__:<module>:51 - 75 fietsen opgehaald
# 2026-04-19 12:35:10.974 | INFO     | __main__:<module>:60 - 75 fietsen geladen
# 2026-04-19 12:35:10.976 | INFO     | __main__:<module>:65 - 4 filialen opgehaald
# 2026-04-19 12:35:10.982 | INFO     | __main__:<module>:74 - 4 filialen geladen
# 2026-04-19 12:35:10.983 | INFO     | __main__:<module>:79 - 10 monteurs opgehaald
# 2026-04-19 12:35:10.987 | INFO     | __main__:<module>:88 - 10 monteurs geladen
# 2026-04-19 12:35:10.989 | INFO     | __main__:<module>:93 - 25 klanten opgehaald
# 2026-04-19 12:35:10.995 | INFO     | __main__:<module>:102 - 25 klanten geladen
# 2026-04-19 12:35:10.997 | INFO     | __main__:<module>:107 - 150 verkoop opgehaald
# 2026-04-19 12:35:11.001 | INFO     | __main__:<module>:116 - 150 verkoop geladen
# 2026-04-19 12:35:11.002 | INFO     | __main__:<module>:128 - Database connecties gesloten

# %% [markdown]
# Toevoegen van een extra rij

# %%
# We voegen een extra rij toe aan de Operationele Database (Fietsverkoop)

# We maken eerst de connectie met de Operationele Database
source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_2_Fietsverkoop.db')
source_cursor = source_conn.cursor()

# We voegen een extra rij toe aan het tabel van Fiets.

sql_insert = """
INSERT INTO Fiets 
VALUES (1500, 'Stadsfiets', 'Gazelle', 'Classic', 599.99, 400.00, 'Zwart', 1)
"""

source_cursor.execute(sql_insert)
source_conn.commit()

source_cursor.close()
source_conn.close()

# %% [markdown]
# Wijzigen van de extra rij

# %%
# We wijzigen deze rij in de Operationele Database.

# We maken eerst de connectie met de Operationele Database
source_conn = source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_2_Fietsverkoop.db')
source_cursor = source_conn.cursor()

# We wijzigen de rij van kleur zwart naar kleur blauw
sql_update = """
UPDATE Fiets
SET kleur = 'Blauw'
WHERE fietsnr = 1500
"""

source_cursor.execute(sql_update)
source_conn.commit()

source_cursor.close()
source_conn.close()

# %% [markdown]
# Verwijderen van de extra rij

# %%
# We verwijderen de rij in de Operationele Database.

# We maken eerst de connectie met de Operationele Database
source_conn = source_conn = sqlite3.connect('../../Databronnen/BikeToDrive_2_Fietsverkoop.db')
source_cursor = source_conn.cursor()

# We deleten de fiets met PK = 1500
sql_delete = """
DELETE FROM Fiets
WHERE fietsnr = 1500
"""

source_cursor.execute(sql_delete)
source_conn.commit()

source_cursor.close()
source_conn.close()
