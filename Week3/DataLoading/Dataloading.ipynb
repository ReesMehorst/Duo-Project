# %%
import pandas as pd
import sqlite3
from loguru import logger

doel_conn = sqlite3.connect('../../BikeToDrive_V3_OLTP.db', timeout=30)
doel_cursor = doel_conn.cursor()

# %% [markdown]
# Accessoire_Inkoop

# %%
source_conn = sqlite3.connect('../../BikeToDrive_4_Accessoire_Inkoop.db')
source_cursor = source_conn.cursor()

source_cursor.execute("SELECT * FROM Leverancier")
Leverancier = source_cursor.fetchall()
for row in Leverancier:
    insert_statement = "INSERT INTO Accessoire_Inkoop_Leverancier VALUES ("
    insert_statement += str(row[0]) + ", "
    insert_statement += "'" + row[1] + "', "
    insert_statement += "'" + row[2] + "', "
    insert_statement += "'" + row[3] + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Accessoire")
Accessoire = source_cursor.fetchall()

for row in Accessoire:
    insert_statement = "INSERT INTO Accessoire_Inkoop_Accessoire VALUES ("
    insert_statement += str(row[0]) + ", "
    insert_statement += "'" + row[1] + "', "
    insert_statement += str(row[2]) + ", "
    insert_statement += str(row[3]) + ", "
    insert_statement += "'" + row[4] + "', "
    insert_statement += str(row[5])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Accessoire_Inkoop")
Accessoire_Inkoop = source_cursor.fetchall()
for row in Accessoire_Inkoop:
    insert_statement = "INSERT INTO Accessoire_Inkoop VALUES ("
    insert_statement += str(row[0]) + ", "
    insert_statement += str(row[1]) + ", "
    insert_statement += str(row[2]) + ", "
    insert_statement += str(row[3]) + ", "
    insert_statement += str(row[4])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

doel_conn.commit()
source_cursor.close()
doel_cursor.close()
source_conn.close()
doel_conn.close()

# %% [markdown]
# Accessoire_Verkoop

# %%
source_conn = sqlite3.connect('../../BikeToDrive_1_Accessoireverkoop.db')
source_cursor = source_conn.cursor()

source_cursor.execute("SELECT * FROM Leverancier")
Leverancier = source_cursor.fetchall()
for row in Leverancier:
    insert_statement = "INSERT INTO Accessoire_Verkoop_Leverancier VALUES ("
    insert_statement += str(row[0]) + ", "
    insert_statement += "'" + row[1] + "', "
    insert_statement += "'" + row[2] + "', "
    insert_statement += "'" + row[3] + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Accessoire")
Accessoire = source_cursor.fetchall()

for row in Accessoire:
    insert_statement = "INSERT INTO Accessoire_Verkoop_Accessoire VALUES ("
    insert_statement += str(row[0]) + ", "
    insert_statement += "'" + row[1] + "', "
    insert_statement += str(row[2]) + ", "
    insert_statement += str(row[3]) + ", "
    insert_statement += "'" + row[4] + "', "
    insert_statement += str(row[5])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Klant")
Klant = source_cursor.fetchall()
for row in Klant:
    insert_statement = "INSERT INTO Accessoire_Verkoop_Klant VALUES ("
    insert_statement += str(row[0]) + ", "
    insert_statement += "'" + row[1] + "', "
    insert_statement += "'" + row[2] + "', "
    insert_statement += "'" + row[3] + "', "
    insert_statement += "'" + row[4] + "', "
    insert_statement += "'" + row[5] + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Filiaal")
Filiaal = source_cursor.fetchall()
for row in Filiaal:
    insert_statement = "INSERT INTO Accessoire_Verkoop_Filiaal VALUES ("
    insert_statement += str(row[0]) + ", "
    insert_statement += "'" + row[1] + "', "
    insert_statement += "'" + row[2] + "', "
    insert_statement += "'" + row[3] + "'"
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

source_cursor.execute("SELECT * FROM Monteur")
Monteur = source_cursor.fetchall()
for row in Monteur:
    insert_statement = "INSERT INTO Accessoire_Verkoop_Monteur VALUES ("
    insert_statement += str(row[0]) + ", "
    insert_statement += "'" + row[1] + "', "
    insert_statement += "'" + row[2] + "', "
    insert_statement += str(row[3])  + ", "
    insert_statement += str(row[4])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")


source_cursor.execute("SELECT * FROM Accessoire_Verkoop")
Accessoire_Verkoop = source_cursor.fetchall()
for row in Accessoire_Verkoop:
    insert_statement = "INSERT INTO Accessoire_Verkoop VALUES ("
    insert_statement += str(row[0]) + ", "
    insert_statement += str(row[1]) + ", "
    insert_statement += str(row[2]) + ", "
    insert_statement += str(row[3]) + ", "
    insert_statement += str(row[4]) + ", "
    insert_statement += str(row[5]) + ", "
    insert_statement += str(row[6])
    insert_statement += ");"

    try:
        doel_cursor.execute(insert_statement)
    except:
        logger.warning(f"FAILED: {insert_statement}")

doel_conn.commit()
source_cursor.close()
doel_cursor.close()
source_conn.close()
doel_conn.close()
# Out:
# 2026-03-09 13:03:43.837 | WARNING  | __main__:<module>:17 - FAILED: INSERT INTO Accessoire_Verkoop_Leverancier VALUES (1, 'BikeParts BV', 'Fietsenstraat 12', 'Amsterdam');
# 2026-03-09 13:03:43.839 | WARNING  | __main__:<module>:17 - FAILED: INSERT INTO Accessoire_Verkoop_Leverancier VALUES (2, 'CycleSupplies', 'Rembrandtlaan 7', 'Rotterdam');
# 2026-03-09 13:03:43.839 | WARNING  | __main__:<module>:17 - FAILED: INSERT INTO Accessoire_Verkoop_Leverancier VALUES (3, 'TwoWheels Trading', 'Marktplein 5', 'Den Haag');
# 2026-03-09 13:03:43.840 | WARNING  | __main__:<module>:17 - FAILED: INSERT INTO Accessoire_Verkoop_Leverancier VALUES (4, 'DutchBike Import', 'Kade 22', 'Leiden');
# 2026-03-09 13:03:43.842 | WARNING  | __main__:<module>:17 - FAILED: INSERT INTO Accessoire_Verkoop_Leverancier VALUES (5, 'UrbanGear NL', 'Stationsweg 15', 'Utrecht');
# 2026-03-09 13:03:43.844 | WARNING  | __main__:<module>:35 - FAILED: INSERT INTO Accessoire_Verkoop_Accessoire VALUES (1, 'LED voorlamp', 14.99, 8.5, 'Verlichting', 1);
# 2026-03-09 13:03:43.845 | WARNING  | __main__:<module>:35 - FAILED: INSERT INTO Accessoire_Verkoop_Accessoire VALUES (2, 'LED achterlicht', 12.99, 7.25, 'Verlichting', 1);
# 2026-03-09 13:03:43.846 | WARNING  | __main__:<module>:35 - FAILED: INSERT INTO Accessoire_Verkoop_Accessoire VALUES (3, 'USB-oplaadbare fietslamp', 24.95, 15.0, 'Verlichting', 1);
# 2026-03-09 13:03:43.848 | WARNING  | __main__:<module>:35 - FAILED: INSERT INTO Accessoire_Verkoop_Accessoire VALUES (4, 'Ringslot AXA', 19.95, 11.4, 'Sloten', 1);
# 2026-03-09 13:03:43.850 | WARNING  | __main__:<module>:35 - FAILED: INSERT INTO Accessoire_Verkoop_Accessoire VALUES (5, 'Ketting met cijferslot', 17.5, 10.0, 'Sloten', 2);
# 2026-03-09 13:03:43.851 | WARNING  | __main__:<module>:35 - FAILED: INSERT INTO Accessoire_Verkoop_Accessoire VALUES (6, 'U-slot met beugel', 29.99, 18.75, 'Sloten', 2);
# 2026-03-09 13:03:43.853 | WARNING  | __main__:<module>:35 - FAILED: INSERT INTO Accessoire_Verkoop_Accessoire VALUES (7, 'Dubbele fietstas zwart', 39.95, 24.9, 'Tassen', 2);
# 2026-03-09 13:03:43.854 | WARNING  | __main__:<module>:35 - FAILED: INSERT INTO Accessoire_Verkoop_Accessoire VALUES (8, 'Enkele schouderfietstas', 27.5, 16.8, 'Tassen', 3);
# 2026-03-09 13:03:43.856 | WARNING  | __main__:<module>:35 - FAILED: INSERT INTO Accessoire_Verkoop_Accessoire VALUES (9, 'Waterdichte zadeltas', 14.25, 8.95, 'Tassen', 3);
# 2026-03-09 13:03:43.857 | WARNING  | __main__:<module>:35 - FAILED: INSERT INTO Accessoire_Verkoop_Accessoire VALUES (10, 'Kinderfietsmand roze', 11.99, 6.6, 'Tassen', 4);
# 2026-03-09 13:03:43.859 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (1, 'Jan Jansen', 'Kerkstraat 12', 'Amsterdam', 'M', '1985-03-22');
# 2026-03-09 13:03:43.860 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (2, 'Sophie de Boer', 'Lindelaan 8', 'Rotterdam', 'V', '1990-07-11');
# 2026-03-09 13:03:43.861 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (3, 'Pieter Visser', 'Havenstraat 3', 'Den Haag', 'M', '1978-11-05');
# 2026-03-09 13:03:43.862 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (4, 'Emma Smit', 'Boomgaard 22', 'Haarlem', 'V', '1995-02-18');
# 2026-03-09 13:03:43.864 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (5, 'Tom Bakker', 'Stationsweg 44', 'Leiden', 'M', '1982-09-09');
# 2026-03-09 13:03:43.865 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (6, 'Lisa Meijer', 'Dijkstraat 10', 'Zaandam', 'V', '1993-12-30');
# 2026-03-09 13:03:43.866 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (7, 'Bart de Vries', 'Brouwersgracht 7', 'Delft', 'M', '1976-06-06');
# 2026-03-09 13:03:43.868 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (8, 'Julia van Dijk', 'Plataanlaan 5', 'Hoorn', 'V', '2000-01-15');
# 2026-03-09 13:03:43.869 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (9, 'Kevin Mol', 'Singel 99', 'Alkmaar', 'M', '1989-08-01');
# 2026-03-09 13:03:43.870 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (10, 'Nina Groen', 'Waterstraat 16', 'Schiedam', 'V', '1991-05-25');
# 2026-03-09 13:03:43.871 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (11, 'Daan Willems', 'Parklaan 31', 'Haarlem', 'M', '1987-10-12');
# 2026-03-09 13:03:43.872 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (12, 'Eva Vos', 'Zomerweg 2', 'Zoetermeer', 'V', '1996-04-03');
# 2026-03-09 13:03:43.873 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (13, 'Rik de Jong', 'Noorderstraat 88', 'Hilversum', 'M', '1980-12-21');
# 2026-03-09 13:03:43.875 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (14, 'Mila Kuipers', 'Heemraadssingel 15', 'Rotterdam', 'V', '1998-09-17');
# 2026-03-09 13:03:43.875 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (15, 'Sam Reinders', 'Beethovenlaan 13', 'Haarlem', 'M', '1983-01-29');
# 2026-03-09 13:03:43.876 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (16, 'Fleur Schouten', 'Tulpenstraat 5', 'Amsterdam', 'V', '1994-06-08');
# 2026-03-09 13:03:43.878 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (17, 'Lars van den Berg', 'Kade 101', 'Leiden', 'M', '1988-03-02');
# 2026-03-09 13:03:43.878 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (18, 'Tess van Leeuwen', 'Markt 22', 'Dordrecht', 'V', '1997-07-19');
# 2026-03-09 13:03:43.879 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (19, 'Jesse van Dam', 'Zuidlaan 7', 'Alphen aan den Rijn', 'M', '1981-11-27');
# 2026-03-09 13:03:43.880 | WARNING  | __main__:<module>:52 - FAILED: INSERT INTO Accessoire_Verkoop_Klant VALUES (20, 'Noa Blom', 'Vondelstraat 18', 'Zaandam', 'V', '2002-02-10');
# 2026-03-09 13:03:43.883 | WARNING  | __main__:<module>:67 - FAILED: INSERT INTO Accessoire_Verkoop_Filiaal VALUES (1, 'BikeWorld Amsterdam', 'Prinsengracht 100', 'Noord-Holland');
# 2026-03-09 13:03:43.885 | WARNING  | __main__:<module>:67 - FAILED: INSERT INTO Accessoire_Verkoop_Filiaal VALUES (2, 'FietsGigant Haarlem', 'Grote Markt 22', 'Noord-Holland');
# 2026-03-09 13:03:43.886 | WARNING  | __main__:<module>:67 - FAILED: INSERT INTO Accessoire_Verkoop_Filiaal VALUES (3, 'FietsExpress Rotterdam', 'Coolsingel 55', 'Zuid-Holland');
# 2026-03-09 13:03:43.887 | WARNING  | __main__:<module>:67 - FAILED: INSERT INTO Accessoire_Verkoop_Filiaal VALUES (4, 'CycleCity Leiden', 'Breestraat 48', 'Zuid-Holland');
# 2026-03-09 13:03:43.889 | WARNING  | __main__:<module>:83 - FAILED: INSERT INTO Accessoire_Verkoop_Monteur VALUES (1, 'Tom van Dijk', 'Amsterdam', 19.5, 1);
# 2026-03-09 13:03:43.890 | WARNING  | __main__:<module>:83 - FAILED: INSERT INTO Accessoire_Verkoop_Monteur VALUES (2, 'Lisa Verhoeven', 'Amstelveen', 18.75, 1);
# 2026-03-09 13:03:43.891 | WARNING  | __main__:<module>:83 - FAILED: INSERT INTO Accessoire_Verkoop_Monteur VALUES (3, 'Kevin Jaspers', 'Zaandam', 20.0, 1);
# 2026-03-09 13:03:43.892 | WARNING  | __main__:<module>:83 - FAILED: INSERT INTO Accessoire_Verkoop_Monteur VALUES (4, 'Romy Willems', 'Haarlem', 17.8, 2);
# 2026-03-09 13:03:43.893 | WARNING  | __main__:<module>:83 - FAILED: INSERT INTO Accessoire_Verkoop_Monteur VALUES (5, 'Daan de Groot', 'Rotterdam', 21.0, 3);
# 2026-03-09 13:03:43.894 | WARNING  | __main__:<module>:83 - FAILED: INSERT INTO Accessoire_Verkoop_Monteur VALUES (6, 'Sophie de Leeuw', 'Schiedam', 19.9, 3);
# 2026-03-09 13:03:43.895 | WARNING  | __main__:<module>:83 - FAILED: INSERT INTO Accessoire_Verkoop_Monteur VALUES (7, 'Mark van Vliet', 'Dordrecht', 20.25, 3);
# 2026-03-09 13:03:43.897 | WARNING  | __main__:<module>:83 - FAILED: INSERT INTO Accessoire_Verkoop_Monteur VALUES (8, 'Jesse Peters', 'Leiden', 16.95, 4);
# 2026-03-09 13:03:43.898 | WARNING  | __main__:<module>:83 - FAILED: INSERT INTO Accessoire_Verkoop_Monteur VALUES (9, 'Eva Meijer', 'Zoetermeer', 18.4, 4);
# 2026-03-09 13:03:43.899 | WARNING  | __main__:<module>:83 - FAILED: INSERT INTO Accessoire_Verkoop_Monteur VALUES (10, 'Milan de Bruin', 'Zaandam', 17.25, 2);

# %% [markdown]
# Onderhoud

# %% [markdown]
# Fiets_Inkoop

# %% [markdown]
# Fiets_Verkoop
